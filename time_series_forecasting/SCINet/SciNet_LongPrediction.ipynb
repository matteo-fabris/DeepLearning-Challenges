# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive1')
# Out:
# Mounted at /gdrive1

# %%
# %cd /gdrive1/My Drive/ANN/CH2/Tests
# Out:
# /gdrive1/My Drive/ANN/CH2/Tests

# %% [markdown]
# ### Import libraries

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
plt.rc('font', size=16)
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %% [markdown]
# # Initial Setup

# %%
# Random seed for reproducibility
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset = pd.read_csv('Training.csv')
print(dataset.shape)
dataset.head()
# Out:
# (68528, 7)
#    Sponginess  Wonder level  ...  Soap slipperiness  Hype root
# 0     7.97698       4.33494  ...          51.681460    3.65434
# 1     8.07824       4.44616  ...          51.563598    3.47672
# 2     8.02844       4.22372  ...          50.863080    3.47672
# 3     8.02844       4.22372  ...          45.841581    3.47672
# 4     7.87572       4.44616  ...          47.126421    3.47672
#
# [5 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68528 entries, 0 to 68527
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sponginess          68528 non-null  float64
#  1   Wonder level        68528 non-null  float64
#  2   Crunchiness         68528 non-null  float64
#  3   Loudness on impact  68528 non-null  float64
#  4   Meme creativity     68528 non-null  float64
#  5   Soap slipperiness   68528 non-null  float64
#  6   Hype root           68528 non-null  float64
# dtypes: float64(7)
# memory usage: 3.7 MB

# %%
corrMatrix = dataset.corr()
plt.figure(figsize = (16,16))
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
inspect_dataframe(dataset, dataset.columns)

# %% [markdown]
# Sequential Train-Test split and normalization

# %%
# Normalize both features and labels
X_min = dataset.min()
X_max = dataset.max()

validation_size = 1500
X_train_raw = dataset.iloc[:-validation_size]
X_validation_raw = dataset.iloc[-validation_size:]
print(X_train_raw.shape, X_validation_raw.shape)

X_train_raw = (X_train_raw-X_min)/(X_max-X_min)
X_validation_raw = (X_validation_raw-X_min)/(X_max-X_min)

plt.figure(figsize=(17,5))
plt.plot(X_train_raw.Sponginess, label='Train (Sponginess)')
plt.plot(X_validation_raw.Sponginess, label='Validation (Sponginess)')
plt.title('Train-Test Split')
plt.legend()
plt.show()
# Out:
# (67028, 7) (1500, 7)

# %%
def build_sequences(df, target_labels=['pollution'], window=200, stride=20, telescope=100):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float64')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float64')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
# NEW VERSION
def build_sequences(df, target_labels=['pollution'], window=200, stride=20, telescope=100):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %% [markdown]
# # V 3.0

# %% [markdown]
# ### SciNet

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
window = 720
stride = 4

# %%
from typing import Tuple
import tensorflow as tf
from tensorflow.keras.regularizers import L1L2


class InnerConv1DBlock(tf.keras.layers.Layer):
    def __init__(self, filters: int, h: float, kernel_size: int, neg_slope: float = .01, dropout: float = .5, **kwargs):
        if filters <= 0 or h <= 0:
            raise ValueError('filters and h must be positive')
        super(InnerConv1DBlock, self).__init__(**kwargs)
        self.conv1d = tf.keras.layers.Conv1D(max(round(h * filters), 1), kernel_size, padding='same')
        self.leakyrelu = tf.keras.layers.LeakyReLU(neg_slope)

        self.dropout = tf.keras.layers.Dropout(dropout)

        self.conv1d2 = tf.keras.layers.Conv1D(filters, kernel_size, padding='same')
        self.tanh = tf.keras.activations.tanh

    def call(self, input_tensor, training=None):
        x = self.conv1d(input_tensor)
        x = self.leakyrelu(x)

        if training:
            x = self.dropout(x)

        x = self.conv1d2(x)
        x = self.tanh(x)
        return x


class SciBlock(tf.keras.layers.Layer):
    def __init__(self, features: int, kernel_size: int, h: int, **kwargs):
        """
        :param features: number of features in the output
        :param kernel_size: kernel size of the convolutional layers
        :param h: scaling factor for convolutional module
        """

        super(SciBlock, self).__init__(**kwargs)
        self.features = features
        self.kernel_size = kernel_size
        self.h = h

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'features': self.features,
            'kernel_size': self.kernel_size,
            'h': self.h,
        })
        return config

    def build(self, input_shape):
        self.conv1ds = {k: InnerConv1DBlock(filters=self.features, h=self.h, kernel_size=self.kernel_size, name=k)
                        for k in ['psi', 'phi', 'eta', 'rho']}  # regularize?
        super().build(input_shape)
        # [layer.build(input_shape) for layer in self.conv1ds.values()]  # unneeded?

    def call(self, inputs, training=None):
        F_odd, F_even = inputs[:, ::2], inputs[:, 1::2]

        # Interactive learning as described in the paper
        F_s_odd = F_odd * tf.math.exp(self.conv1ds['phi'](F_even))
        F_s_even = F_even * tf.math.exp(self.conv1ds['psi'](F_odd))

        F_prime_odd = F_s_odd + self.conv1ds['rho'](F_s_even)
        F_prime_even = F_s_even - self.conv1ds['eta'](F_s_odd)

        return F_prime_odd, F_prime_even


class Interleave(tf.keras.layers.Layer):
    """A layer used to reverse the even-odd split operation."""

    def __init__(self, **kwargs):
        super(Interleave, self).__init__(**kwargs)

    def interleave(self, slices):
        if not slices:
            return slices
        elif len(slices) == 1:
            return slices[0]

        mid = len(slices) // 2
        even = self.interleave(slices[:mid])
        odd = self.interleave(slices[mid:])

        shape = tf.shape(even)
        return tf.reshape(tf.stack([even, odd], axis=3), (shape[0], shape[1] * 2, shape[2]))

    def call(self, inputs):
        return self.interleave(inputs)


class SciNet(tf.keras.layers.Layer):
    def __init__(self, horizon: int, features: int, levels: int, h: int, kernel_size: int,
                 regularizer: Tuple[float, float] = (0, 0), **kwargs):
        """
        :param horizon: number of time stamps in output
        :param features: number of features in output
        :param levels: height of the binary tree + 1
        :param h: scaling factor for convolutional module in each SciBlock
        :param kernel_size: kernel size of convolutional module in each SciBlock
        :param regularizer: activity regularization (not implemented)
        """

        if levels < 1:
            raise ValueError('Must have at least 1 level')
        super(SciNet, self).__init__(**kwargs)
        self.horizon = horizon
        self.features = features
        self.levels = levels
        self.interleave = Interleave()
        self.flatten = tf.keras.layers.Flatten()
        self.dense = tf.keras.layers.Dense(
            horizon * features,
            kernel_regularizer=L1L2(0.001, 0.01),
            # activity_regularizer=L1L2(0.001, 0.01)
        )
        # self.regularizer = tf.keras.layers.ActivityRegularization(l1=regularizer[0], l2=regularizer[1])

        # tree of sciblocks
        self.sciblocks = [SciBlock(features=features, kernel_size=kernel_size, h=h)
                          for _ in range(2 ** levels - 1)]

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'horizon': self.horizon,
            'features': self.features,
            'levels': self.levels,
            'interleave': self.interleave,
            'flatten': self.flatten,
            'dense': self.dense,
            'sciblocks': self.sciblocks,
        })
        return config

    def build(self, input_shape):
        if input_shape[1] / 2 ** self.levels % 1 != 0:
            raise ValueError(f'timestamps {input_shape[1]} must be evenly divisible by a tree with '
                             f'{self.levels} levels')
        super().build(input_shape)
        # [layer.build(input_shape) for layer in self.sciblocks]  # input_shape

    def call(self, inputs, training=None):
        # cascade input down a binary tree of sci-blocks
        lvl_inputs = [inputs]  # inputs for current level of the tree
        for i in range(self.levels):
            i_end = 2 ** (i + 1) - 1
            i_start = i_end - 2 ** i
            lvl_outputs = [output for j, tensor in zip(range(i_start, i_end), lvl_inputs)
                           for output in self.sciblocks[j](tensor)]
            lvl_inputs = lvl_outputs

        x = self.interleave(lvl_outputs)
        x += inputs

        # not sure if this is the correct way of doing it. The paper merely said to use a fully connected layer to
        # produce an output. Can't use TimeDistributed wrapper. It would force the layer's timestamps to match that of
        # the input -- something SCINet is supposed to solve
        x = self.flatten(x)
        x = self.dense(x)
        x = tf.reshape(x, (-1, self.horizon, self.features))

        return x


class StackedSciNet(tf.keras.layers.Layer):
    def __init__(self, horizon: int, features: int, stacks: int, levels: int, h: int, kernel_size: int,
                 regularizer: Tuple[float, float] = (0, 0), **kwargs):
        """
        :param horizon: number of time stamps in output
        :param stacks: number of stacked SciNets
        :param levels: number of levels for each SciNet
        :param h: scaling factor for convolutional module in each SciBlock
        :param kernel_size: kernel size of convolutional module in each SciBlock
        :param regularizer: activity regularization (not implemented)
        """

        if stacks < 1:
            raise ValueError('Must have at least 1 stack')
        super(StackedSciNet, self).__init__(**kwargs)
        self.horizon = horizon
        self.features = features
        self.stacks = stacks
        self.levels = levels
        self.h = h
        self.kernel_size = kernel_size
        self.regularizer = regularizer
        self.scinets = [SciNet(horizon=horizon, features=features, levels=levels, h=h, kernel_size=kernel_size,
                               regularizer=regularizer) for _ in range(stacks)]
        self.mse_fn = tf.keras.metrics.MeanSquaredError()
        self.mae_fn = tf.keras.metrics.MeanAbsoluteError()

    # def build(self, input_shape):
    #     super().build(input_shape)
    #     [stack.build(input_shape) for stack in self.scinets]

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'horizon': self.horizon,
            'features': self.features,
            'stacks': self.stacks,
            'levels': self.levels,
            'h': self.h,
            'kernel_size': self.kernel_size,
            'regularizer': self.regularizer,
        })
        return config

    def call(self, inputs, targets=None, sample_weights=None, training=None):
        outputs = []
        for scinet in self.scinets:
            x = scinet(inputs)
            outputs.append(x)  # keep each stack's output for intermediate supervision
            inputs = tf.concat([x, inputs[:, x.shape[1]:, :]], axis=1)

        if targets is not None:
            # Calculate metrics
            mse = self.mse_fn(targets, x, sample_weights)
            mae = self.mae_fn(targets, x, sample_weights)
            self.add_metric(mse, name='mean_squared_error')
            self.add_metric(mae, name='mean_absolute_error')

            if training:
                # Calculate loss as sum of mean of norms of differences between output and input feature vectors for
                # each stack
                stacked_outputs = tf.stack(outputs)
                differences = stacked_outputs - targets
                loss = tf.linalg.normalize(differences, axis=1)[1]
                loss = tf.reshape(loss, (-1, self.horizon))
                loss = tf.reduce_sum(loss, 1)
                loss = loss / self.horizon
                loss = tf.reduce_sum(loss)
                self.add_loss(loss)

        return x

# %%
target_labels = dataset.columns
telescope = 576

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, window, stride, telescope)

X_validation, y_validation = build_sequences(X_validation_raw, target_labels, window, stride, telescope)

X_train.shape, y_train.shape, X_validation.shape, y_validation.shape
# Out:
# ((16596, 720, 7), (16596, 576, 7), (36, 720, 7), (36, 576, 7))

# %%
inspect_multivariate(X_train, y_train, target_labels, telescope)

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
batch_size = 128
epochs = 200

# %%
def make_model(input_shape, output_shape):
    inputs = tf.keras.Input(shape=(window, 7), name='inputs')
    # x = SciNet(horizon, levels=L, h=h, kernel_size=kernel_size)(inputs)
    # model = tf.keras.Model(inputs, x)
    targets = tf.keras.Input(shape=(telescope, 7), name='targets')
    predictions = StackedSciNet(horizon=telescope, features=input_shape[-1], stacks=2, levels=2, h=4,
                                kernel_size=5,
                                regularizer=(1e-3, 0.1))(inputs, targets)
    model = tf.keras.Model(inputs=[inputs, targets], outputs=predictions)

    model.summary()
    tf.keras.utils.plot_model(model, to_file='modelDiagram.png', show_shapes=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse',
                  metrics=['mean_squared_error', 'mean_absolute_error'])
    return model

# %%
with strategy.scope():
  model = make_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, 720, 7)]     0           []
#
#  targets (InputLayer)           [(None, 576, 7)]     0           []
#
#  stacked_sci_net_1 (StackedSciN  (None, 576, 7)      40698504    ['inputs[0][0]',
#  et)                                                              'targets[0][0]']
#
# ==================================================================================================
# Total params: 40,698,504
# Trainable params: 40,698,504
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, 720, 7)]     0           []
#
#  targets (InputLayer)           [(None, 576, 7)]     0           []
#
#  stacked_sci_net_1 (StackedSciN  (None, 576, 7)      40698504    ['inputs[0][0]',
#  et)                                                              'targets[0][0]']
#
# ==================================================================================================
# Total params: 40,698,504
# Trainable params: 40,698,504
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = {'inputs': X_train, 'targets': y_train},
    y = y_train,
    validation_data={'inputs': X_validation, 'targets': y_validation},
    batch_size = batch_size,
    epochs = epochs,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-8)
    ]
).history
# Out:
# Epoch 1/200
# 130/130 [==============================] - 71s 493ms/step - loss: 658.4016 - mean_squared_error: 10.1084 - mean_absolute_error: 0.9509 - val_loss: 390.2663 - val_mean_squared_error: 0.0532 - val_mean_absolute_error: 0.1887 - lr: 0.0010
# Epoch 2/200
# 130/130 [==============================] - 63s 484ms/step - loss: 312.5338 - mean_squared_error: 0.0255 - mean_absolute_error: 0.1230 - val_loss: 201.1457 - val_mean_squared_error: 0.0694 - val_mean_absolute_error: 0.2375 - lr: 0.0010
# Epoch 3/200
# 130/130 [==============================] - 63s 484ms/step - loss: 156.1274 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0887 - val_loss: 88.1903 - val_mean_squared_error: 0.0662 - val_mean_absolute_error: 0.2339 - lr: 0.0010
# Epoch 4/200
# 130/130 [==============================] - 63s 485ms/step - loss: 74.9656 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0825 - val_loss: 36.6145 - val_mean_squared_error: 0.0521 - val_mean_absolute_error: 0.2031 - lr: 0.0010
# Epoch 5/200
# 130/130 [==============================] - 63s 485ms/step - loss: 41.3584 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0827 - val_loss: 17.0047 - val_mean_squared_error: 0.0463 - val_mean_absolute_error: 0.1938 - lr: 0.0010
# Epoch 6/200
# 130/130 [==============================] - 63s 486ms/step - loss: 28.6955 - mean_squared_error: 0.0111 - mean_absolute_error: 0.0790 - val_loss: 9.6569 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1777 - lr: 0.0010
# Epoch 7/200
# 130/130 [==============================] - 63s 487ms/step - loss: 23.7175 - mean_squared_error: 0.0101 - mean_absolute_error: 0.0750 - val_loss: 6.9220 - val_mean_squared_error: 0.0251 - val_mean_absolute_error: 0.1336 - lr: 0.0010
# Epoch 8/200
# 130/130 [==============================] - 63s 487ms/step - loss: 22.2011 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0754 - val_loss: 5.8748 - val_mean_squared_error: 0.0187 - val_mean_absolute_error: 0.1111 - lr: 0.0010
# Epoch 9/200
# 130/130 [==============================] - 63s 486ms/step - loss: 21.2409 - mean_squared_error: 0.0096 - mean_absolute_error: 0.0724 - val_loss: 5.3403 - val_mean_squared_error: 0.0197 - val_mean_absolute_error: 0.1168 - lr: 0.0010
# Epoch 10/200
# 130/130 [==============================] - 63s 485ms/step - loss: 20.9870 - mean_squared_error: 0.0096 - mean_absolute_error: 0.0722 - val_loss: 5.1276 - val_mean_squared_error: 0.0166 - val_mean_absolute_error: 0.1021 - lr: 0.0010
# Epoch 11/200
# 130/130 [==============================] - 63s 487ms/step - loss: 20.6431 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0713 - val_loss: 4.9978 - val_mean_squared_error: 0.0179 - val_mean_absolute_error: 0.1099 - lr: 0.0010
# Epoch 12/200
# 130/130 [==============================] - 63s 488ms/step - loss: 20.6132 - mean_squared_error: 0.0093 - mean_absolute_error: 0.0712 - val_loss: 4.9334 - val_mean_squared_error: 0.0157 - val_mean_absolute_error: 0.1019 - lr: 0.0010
# Epoch 13/200
# 130/130 [==============================] - 63s 482ms/step - loss: 20.4153 - mean_squared_error: 0.0092 - mean_absolute_error: 0.0704 - val_loss: 4.9564 - val_mean_squared_error: 0.0162 - val_mean_absolute_error: 0.1064 - lr: 0.0010
# Epoch 14/200
# 130/130 [==============================] - 63s 486ms/step - loss: 20.2048 - mean_squared_error: 0.0090 - mean_absolute_error: 0.0696 - val_loss: 4.8401 - val_mean_squared_error: 0.0166 - val_mean_absolute_error: 0.1065 - lr: 0.0010
# Epoch 15/200
# 130/130 [==============================] - 63s 486ms/step - loss: 20.1444 - mean_squared_error: 0.0090 - mean_absolute_error: 0.0695 - val_loss: 4.8287 - val_mean_squared_error: 0.0164 - val_mean_absolute_error: 0.1055 - lr: 0.0010
# Epoch 16/200
# 130/130 [==============================] - 63s 485ms/step - loss: 20.0518 - mean_squared_error: 0.0088 - mean_absolute_error: 0.0687 - val_loss: 5.0125 - val_mean_squared_error: 0.0160 - val_mean_absolute_error: 0.1067 - lr: 0.0010
# Epoch 17/200
# 130/130 [==============================] - 63s 482ms/step - loss: 20.1187 - mean_squared_error: 0.0088 - mean_absolute_error: 0.0689 - val_loss: 4.9875 - val_mean_squared_error: 0.0157 - val_mean_absolute_error: 0.1039 - lr: 0.0010
# Epoch 18/200
# 130/130 [==============================] - 63s 482ms/step - loss: 19.9823 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0680 - val_loss: 5.1452 - val_mean_squared_error: 0.0138 - val_mean_absolute_error: 0.0947 - lr: 0.0010
# Epoch 19/200
# 130/130 [==============================] - 63s 482ms/step - loss: 20.0401 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0672 - val_loss: 5.2934 - val_mean_squared_error: 0.0158 - val_mean_absolute_error: 0.1037 - lr: 0.0010
# Epoch 20/200
# 130/130 [==============================] - 63s 483ms/step - loss: 20.0386 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0667 - val_loss: 5.3280 - val_mean_squared_error: 0.0184 - val_mean_absolute_error: 0.1115 - lr: 0.0010
# Epoch 21/200
# 130/130 [==============================] - 63s 487ms/step - loss: 18.0028 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0642 - val_loss: 3.6936 - val_mean_squared_error: 0.0169 - val_mean_absolute_error: 0.1078 - lr: 5.0000e-04
# Epoch 22/200
# 130/130 [==============================] - 63s 485ms/step - loss: 18.0021 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0643 - val_loss: 3.7659 - val_mean_squared_error: 0.0152 - val_mean_absolute_error: 0.1026 - lr: 5.0000e-04
# Epoch 23/200
# 130/130 [==============================] - 63s 484ms/step - loss: 18.0787 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0643 - val_loss: 3.8105 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0990 - lr: 5.0000e-04
# Epoch 24/200
# 130/130 [==============================] - 62s 480ms/step - loss: 18.1780 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0642 - val_loss: 3.9182 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1131 - lr: 5.0000e-04
# Epoch 25/200
# 130/130 [==============================] - 63s 482ms/step - loss: 18.2464 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0642 - val_loss: 3.9895 - val_mean_squared_error: 0.0148 - val_mean_absolute_error: 0.1024 - lr: 5.0000e-04
# Epoch 26/200
# 130/130 [==============================] - 63s 484ms/step - loss: 18.3133 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0642 - val_loss: 4.1084 - val_mean_squared_error: 0.0140 - val_mean_absolute_error: 0.0963 - lr: 5.0000e-04
# Epoch 27/200
# 130/130 [==============================] - 64s 489ms/step - loss: 16.8671 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0626 - val_loss: 2.8906 - val_mean_squared_error: 0.0151 - val_mean_absolute_error: 0.1014 - lr: 2.5000e-04
# Epoch 28/200
# 130/130 [==============================] - 63s 485ms/step - loss: 16.8207 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0627 - val_loss: 2.9275 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0978 - lr: 2.5000e-04
# Epoch 29/200
# 130/130 [==============================] - 63s 485ms/step - loss: 16.8734 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0627 - val_loss: 3.0194 - val_mean_squared_error: 0.0152 - val_mean_absolute_error: 0.1026 - lr: 2.5000e-04
# Epoch 30/200
# 130/130 [==============================] - 63s 486ms/step - loss: 16.9204 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0626 - val_loss: 3.0439 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0956 - lr: 2.5000e-04
# Epoch 31/200
# 130/130 [==============================] - 63s 485ms/step - loss: 16.9395 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0626 - val_loss: 3.0882 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0901 - lr: 2.5000e-04
# Epoch 32/200
# 130/130 [==============================] - 63s 487ms/step - loss: 17.0526 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0628 - val_loss: 3.1265 - val_mean_squared_error: 0.0152 - val_mean_absolute_error: 0.1000 - lr: 2.5000e-04
# Epoch 33/200
# 130/130 [==============================] - 63s 487ms/step - loss: 16.0496 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0615 - val_loss: 2.3294 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0898 - lr: 1.2500e-04
# Epoch 34/200
# 130/130 [==============================] - 63s 485ms/step - loss: 15.9995 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0616 - val_loss: 2.3516 - val_mean_squared_error: 0.0140 - val_mean_absolute_error: 0.0939 - lr: 1.2500e-04
# Epoch 35/200
# 130/130 [==============================] - 63s 485ms/step - loss: 16.0129 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0616 - val_loss: 2.3809 - val_mean_squared_error: 0.0138 - val_mean_absolute_error: 0.0931 - lr: 1.2500e-04
# Epoch 36/200
# 130/130 [==============================] - 63s 484ms/step - loss: 16.0529 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0617 - val_loss: 2.3849 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0909 - lr: 1.2500e-04
# Epoch 37/200
# 130/130 [==============================] - 63s 487ms/step - loss: 16.0538 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0616 - val_loss: 2.4023 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0880 - lr: 1.2500e-04
# Epoch 38/200
# 130/130 [==============================] - 63s 485ms/step - loss: 16.0857 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0617 - val_loss: 2.3942 - val_mean_squared_error: 0.0131 - val_mean_absolute_error: 0.0898 - lr: 1.2500e-04
# Epoch 39/200
# 130/130 [==============================] - 64s 490ms/step - loss: 15.4680 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0609 - val_loss: 1.9270 - val_mean_squared_error: 0.0141 - val_mean_absolute_error: 0.0925 - lr: 6.2500e-05
# Epoch 40/200
# 130/130 [==============================] - 63s 488ms/step - loss: 15.4161 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0609 - val_loss: 1.9225 - val_mean_squared_error: 0.0123 - val_mean_absolute_error: 0.0877 - lr: 6.2500e-05
# Epoch 41/200
# 130/130 [==============================] - 63s 485ms/step - loss: 15.4133 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0609 - val_loss: 1.9291 - val_mean_squared_error: 0.0126 - val_mean_absolute_error: 0.0882 - lr: 6.2500e-05
# Epoch 42/200
# 130/130 [==============================] - 63s 483ms/step - loss: 15.4291 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0610 - val_loss: 1.9381 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0886 - lr: 6.2500e-05
# Epoch 43/200
# 130/130 [==============================] - 63s 487ms/step - loss: 15.4292 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0609 - val_loss: 1.9193 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0889 - lr: 6.2500e-05
# Epoch 44/200
# 130/130 [==============================] - 63s 485ms/step - loss: 15.4375 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0610 - val_loss: 1.9409 - val_mean_squared_error: 0.0139 - val_mean_absolute_error: 0.0923 - lr: 6.2500e-05
# Epoch 45/200
# 130/130 [==============================] - 63s 486ms/step - loss: 15.4068 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0608 - val_loss: 1.9339 - val_mean_squared_error: 0.0126 - val_mean_absolute_error: 0.0878 - lr: 6.2500e-05
# Epoch 46/200
# 130/130 [==============================] - 63s 486ms/step - loss: 15.4187 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0609 - val_loss: 1.9321 - val_mean_squared_error: 0.0134 - val_mean_absolute_error: 0.0916 - lr: 6.2500e-05
# Epoch 47/200
# 130/130 [==============================] - 63s 485ms/step - loss: 15.4073 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0608 - val_loss: 1.9265 - val_mean_squared_error: 0.0129 - val_mean_absolute_error: 0.0876 - lr: 6.2500e-05
# Epoch 48/200
# 130/130 [==============================] - 63s 484ms/step - loss: 15.4030 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0608 - val_loss: 1.9448 - val_mean_squared_error: 0.0125 - val_mean_absolute_error: 0.0870 - lr: 6.2500e-05
# Epoch 49/200
# 130/130 [==============================] - 63s 487ms/step - loss: 15.0175 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0603 - val_loss: 1.6154 - val_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0901 - lr: 3.1250e-05
# Epoch 50/200
# 130/130 [==============================] - 63s 485ms/step - loss: 14.9639 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0602 - val_loss: 1.6229 - val_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0898 - lr: 3.1250e-05
# Epoch 51/200
# 130/130 [==============================] - 63s 485ms/step - loss: 14.9661 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0603 - val_loss: 1.6175 - val_mean_squared_error: 0.0129 - val_mean_absolute_error: 0.0883 - lr: 3.1250e-05
# Epoch 52/200
# 130/130 [==============================] - 63s 483ms/step - loss: 14.9848 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0604 - val_loss: 1.6190 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0871 - lr: 3.1250e-05
# Epoch 53/200
# 130/130 [==============================] - 64s 489ms/step - loss: 14.9615 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0602 - val_loss: 1.6119 - val_mean_squared_error: 0.0136 - val_mean_absolute_error: 0.0906 - lr: 3.1250e-05
# Epoch 54/200
# 130/130 [==============================] - 64s 489ms/step - loss: 14.9627 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0603 - val_loss: 1.6021 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0877 - lr: 3.1250e-05
# Epoch 55/200
# 130/130 [==============================] - 64s 489ms/step - loss: 14.9548 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0603 - val_loss: 1.6018 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0911 - lr: 3.1250e-05
# Epoch 56/200
# 130/130 [==============================] - 63s 485ms/step - loss: 14.9408 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0602 - val_loss: 1.6087 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0875 - lr: 3.1250e-05
# Epoch 57/200
# 130/130 [==============================] - 63s 484ms/step - loss: 14.9381 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0602 - val_loss: 1.6068 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0833 - lr: 3.1250e-05
# Epoch 58/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.9351 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0602 - val_loss: 1.5980 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0871 - lr: 3.1250e-05
# Epoch 59/200
# 130/130 [==============================] - 63s 484ms/step - loss: 14.9286 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0602 - val_loss: 1.6045 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0908 - lr: 3.1250e-05
# Epoch 60/200
# 130/130 [==============================] - 63s 486ms/step - loss: 14.9243 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0602 - val_loss: 1.5995 - val_mean_squared_error: 0.0131 - val_mean_absolute_error: 0.0896 - lr: 3.1250e-05
# Epoch 61/200
# 130/130 [==============================] - 64s 492ms/step - loss: 14.9088 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0601 - val_loss: 1.5971 - val_mean_squared_error: 0.0129 - val_mean_absolute_error: 0.0875 - lr: 3.1250e-05
# Epoch 62/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.8980 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0601 - val_loss: 1.6017 - val_mean_squared_error: 0.0138 - val_mean_absolute_error: 0.0913 - lr: 3.1250e-05
# Epoch 63/200
# 130/130 [==============================] - 63s 488ms/step - loss: 14.8941 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0601 - val_loss: 1.5950 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0919 - lr: 3.1250e-05
# Epoch 64/200
# 130/130 [==============================] - 63s 484ms/step - loss: 14.8872 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0601 - val_loss: 1.6030 - val_mean_squared_error: 0.0131 - val_mean_absolute_error: 0.0878 - lr: 3.1250e-05
# Epoch 65/200
# 130/130 [==============================] - 63s 488ms/step - loss: 14.8893 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0601 - val_loss: 1.5918 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0863 - lr: 3.1250e-05
# Epoch 66/200
# 130/130 [==============================] - 64s 490ms/step - loss: 14.8675 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0600 - val_loss: 1.5768 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0955 - lr: 3.1250e-05
# Epoch 67/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.8614 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0600 - val_loss: 1.5819 - val_mean_squared_error: 0.0141 - val_mean_absolute_error: 0.0901 - lr: 3.1250e-05
# Epoch 68/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.8590 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0600 - val_loss: 1.5870 - val_mean_squared_error: 0.0134 - val_mean_absolute_error: 0.0892 - lr: 3.1250e-05
# Epoch 69/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.8436 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0600 - val_loss: 1.5801 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0924 - lr: 3.1250e-05
# Epoch 70/200
# 130/130 [==============================] - 63s 488ms/step - loss: 14.8350 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0600 - val_loss: 1.5776 - val_mean_squared_error: 0.0146 - val_mean_absolute_error: 0.0940 - lr: 3.1250e-05
# Epoch 71/200
# 130/130 [==============================] - 64s 490ms/step - loss: 14.8215 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0599 - val_loss: 1.5675 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0906 - lr: 3.1250e-05
# Epoch 72/200
# 130/130 [==============================] - 63s 488ms/step - loss: 14.8158 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0599 - val_loss: 1.5594 - val_mean_squared_error: 0.0136 - val_mean_absolute_error: 0.0890 - lr: 3.1250e-05
# Epoch 73/200
# 130/130 [==============================] - 63s 486ms/step - loss: 14.8032 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0599 - val_loss: 1.5601 - val_mean_squared_error: 0.0132 - val_mean_absolute_error: 0.0878 - lr: 3.1250e-05
# Epoch 74/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.7933 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0599 - val_loss: 1.5716 - val_mean_squared_error: 0.0140 - val_mean_absolute_error: 0.0906 - lr: 3.1250e-05
# Epoch 75/200
# 130/130 [==============================] - 64s 490ms/step - loss: 14.7962 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0599 - val_loss: 1.5568 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0909 - lr: 3.1250e-05
# Epoch 76/200
# 130/130 [==============================] - 64s 491ms/step - loss: 14.7646 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0597 - val_loss: 1.5524 - val_mean_squared_error: 0.0135 - val_mean_absolute_error: 0.0887 - lr: 3.1250e-05
# Epoch 77/200
# 130/130 [==============================] - 64s 489ms/step - loss: 14.7677 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0598 - val_loss: 1.5444 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0863 - lr: 3.1250e-05
# Epoch 78/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.7611 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0598 - val_loss: 1.5360 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0897 - lr: 3.1250e-05
# Epoch 79/200
# 130/130 [==============================] - 63s 484ms/step - loss: 14.7423 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0597 - val_loss: 1.5409 - val_mean_squared_error: 0.0132 - val_mean_absolute_error: 0.0882 - lr: 3.1250e-05
# Epoch 80/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.7359 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0597 - val_loss: 1.5334 - val_mean_squared_error: 0.0136 - val_mean_absolute_error: 0.0882 - lr: 3.1250e-05
# Epoch 81/200
# 130/130 [==============================] - 63s 488ms/step - loss: 14.7236 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0597 - val_loss: 1.5272 - val_mean_squared_error: 0.0136 - val_mean_absolute_error: 0.0900 - lr: 3.1250e-05
# Epoch 82/200
# 130/130 [==============================] - 63s 483ms/step - loss: 14.7042 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0595 - val_loss: 1.5396 - val_mean_squared_error: 0.0132 - val_mean_absolute_error: 0.0874 - lr: 3.1250e-05
# Epoch 83/200
# 130/130 [==============================] - 63s 484ms/step - loss: 14.6890 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0595 - val_loss: 1.5376 - val_mean_squared_error: 0.0134 - val_mean_absolute_error: 0.0887 - lr: 3.1250e-05
# Epoch 84/200
# 130/130 [==============================] - 64s 489ms/step - loss: 14.6830 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0594 - val_loss: 1.5156 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0857 - lr: 3.1250e-05
# Epoch 85/200
# 130/130 [==============================] - 63s 486ms/step - loss: 14.6733 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0594 - val_loss: 1.5168 - val_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0873 - lr: 3.1250e-05
# Epoch 86/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.6600 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0594 - val_loss: 1.5181 - val_mean_squared_error: 0.0136 - val_mean_absolute_error: 0.0885 - lr: 3.1250e-05
# Epoch 87/200
# 130/130 [==============================] - 63s 488ms/step - loss: 14.6618 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0594 - val_loss: 1.5071 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0897 - lr: 3.1250e-05
# Epoch 88/200
# 130/130 [==============================] - 64s 489ms/step - loss: 14.6401 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0593 - val_loss: 1.5070 - val_mean_squared_error: 0.0134 - val_mean_absolute_error: 0.0872 - lr: 3.1250e-05
# Epoch 89/200
# 130/130 [==============================] - 63s 486ms/step - loss: 14.6136 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0591 - val_loss: 1.5122 - val_mean_squared_error: 0.0135 - val_mean_absolute_error: 0.0884 - lr: 3.1250e-05
# Epoch 90/200
# 130/130 [==============================] - 64s 490ms/step - loss: 14.6123 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0591 - val_loss: 1.5069 - val_mean_squared_error: 0.0130 - val_mean_absolute_error: 0.0857 - lr: 3.1250e-05
# Epoch 91/200
# 130/130 [==============================] - 64s 490ms/step - loss: 14.6133 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0591 - val_loss: 1.5013 - val_mean_squared_error: 0.0142 - val_mean_absolute_error: 0.0907 - lr: 3.1250e-05
# Epoch 92/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.6073 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0591 - val_loss: 1.5055 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0845 - lr: 3.1250e-05
# Epoch 93/200
# 130/130 [==============================] - 63s 488ms/step - loss: 14.5883 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0590 - val_loss: 1.4950 - val_mean_squared_error: 0.0131 - val_mean_absolute_error: 0.0869 - lr: 3.1250e-05
# Epoch 94/200
# 130/130 [==============================] - 64s 489ms/step - loss: 14.5750 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0589 - val_loss: 1.4872 - val_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0875 - lr: 3.1250e-05
# Epoch 95/200
# 130/130 [==============================] - 63s 485ms/step - loss: 14.5653 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0589 - val_loss: 1.4895 - val_mean_squared_error: 0.0135 - val_mean_absolute_error: 0.0887 - lr: 3.1250e-05
# Epoch 96/200
# 130/130 [==============================] - 63s 486ms/step - loss: 14.5709 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0589 - val_loss: 1.4906 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0887 - lr: 3.1250e-05
# Epoch 97/200
# 130/130 [==============================] - 64s 489ms/step - loss: 14.5483 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0589 - val_loss: 1.4807 - val_mean_squared_error: 0.0130 - val_mean_absolute_error: 0.0858 - lr: 3.1250e-05
# Epoch 98/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.5589 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0589 - val_loss: 1.4941 - val_mean_squared_error: 0.0129 - val_mean_absolute_error: 0.0858 - lr: 3.1250e-05
# Epoch 99/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.5406 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0588 - val_loss: 1.4877 - val_mean_squared_error: 0.0136 - val_mean_absolute_error: 0.0884 - lr: 3.1250e-05
# Epoch 100/200
# 130/130 [==============================] - 63s 485ms/step - loss: 14.5252 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0587 - val_loss: 1.4830 - val_mean_squared_error: 0.0135 - val_mean_absolute_error: 0.0879 - lr: 3.1250e-05
# Epoch 101/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.5227 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0586 - val_loss: 1.4723 - val_mean_squared_error: 0.0141 - val_mean_absolute_error: 0.0905 - lr: 3.1250e-05
# Epoch 102/200
# 130/130 [==============================] - 63s 486ms/step - loss: 14.5161 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0586 - val_loss: 1.4883 - val_mean_squared_error: 0.0146 - val_mean_absolute_error: 0.0902 - lr: 3.1250e-05
# Epoch 103/200
# 130/130 [==============================] - 63s 487ms/step - loss: 14.5127 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0586 - val_loss: 1.4811 - val_mean_squared_error: 0.0140 - val_mean_absolute_error: 0.0891 - lr: 3.1250e-05
# Epoch 104/200
# 130/130 [==============================] - 63s 486ms/step - loss: 14.5094 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0586 - val_loss: 1.4860 - val_mean_squared_error: 0.0142 - val_mean_absolute_error: 0.0895 - lr: 3.1250e-05
# Epoch 105/200
# 130/130 [==============================] - 63s 486ms/step - loss: 14.4927 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0585 - val_loss: 1.4855 - val_mean_squared_error: 0.0141 - val_mean_absolute_error: 0.0891 - lr: 3.1250e-05
# Epoch 106/200
#  36/130 [=======>......................] - ETA: 45s - loss: 14.5445 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0587
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-e1d96f5c719d> in <module>()
#       8     callbacks = [
#       9         tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
# ---> 10         tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-8)
#      11     ]
#      12 ).history
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('LOSS')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mean_absolute_error'], label='Training', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mean_absolute_error'], label='Validation', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
 model.save('SciNet_30V2.h5')
# model = tfk.models.load_model('AuroregressiveForecasting')

# %%
X_validation = X_train_raw[-window:]
y_validation = X_validation_raw

# %%
reg_telescope = 1000
X_validation_reg =  np.expand_dims(X_validation, axis=0)
y_validation_reg =  np.expand_dims(y_validation, axis=0)

# %%
reg_predictions = np.array([])
X_temp = X_validation_reg
placeholder = np.empty([telescope, 7])
placeholder = np.expand_dims(placeholder, axis=0)
for reg in range(0,reg_telescope,telescope):
    pred_temp = model.predict({'inputs': X_temp, 'targets': placeholder})
    if(len(reg_predictions)==0):
        reg_predictions = pred_temp
    else:
        reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)

# %%
reg_predictions = reg_predictions[0][:1000]

# %%
reg_predictions = np.expand_dims(reg_predictions, axis=0)

# %%
reg_predictions.shape
# Out:
# (1, 1000, 7)

# %%
y_validation_reg.shape
# Out:
# (1, 1000, 7)

# %%
mean_squared_error = tfk.metrics.mse(y_validation_reg.flatten(),reg_predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_validation_reg.flatten(),reg_predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.0057418183>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.056791443>)

# %%
inspect_multivariate_prediction(X_validation_reg, y_validation_reg, reg_predictions, target_labels, reg_telescope)

# %% [markdown]
# # V 3.0 Gradient Optimization

# %% [markdown]
# ### SciNet - W 720 - S 1 - T 16 #6

# %% [markdown]
# SciNet Implementation is an adaptation of open repository: https://github.com/Meatssauce/SCINet

# %%
from typing import Tuple
import tensorflow as tf
from tensorflow.keras.regularizers import L1L2


class InnerConv1DBlock(tf.keras.layers.Layer):
    def __init__(self, filters: int, h: float, kernel_size: int, neg_slope: float = .01, dropout: float = .5, **kwargs):
        if filters <= 0 or h <= 0:
            raise ValueError('filters and h must be positive')
        super(InnerConv1DBlock, self).__init__(**kwargs)
        self.conv1d = tf.keras.layers.Conv1D(max(round(h * filters), 1), kernel_size, padding='same')
        self.leakyrelu = tf.keras.layers.LeakyReLU(neg_slope)

        self.dropout = tf.keras.layers.Dropout(dropout)

        self.conv1d2 = tf.keras.layers.Conv1D(filters, kernel_size, padding='same')
        self.tanh = tf.keras.activations.tanh

    def call(self, input_tensor, training=None):
        x = self.conv1d(input_tensor)
        x = self.leakyrelu(x)

        if training:
            x = self.dropout(x)

        x = self.conv1d2(x)
        x = self.tanh(x)
        return x


class SciBlock(tf.keras.layers.Layer):
    def __init__(self, features: int, kernel_size: int, h: int, **kwargs):
        """
        :param features: number of features in the output
        :param kernel_size: kernel size of the convolutional layers
        :param h: scaling factor for convolutional module
        """

        super(SciBlock, self).__init__(**kwargs)
        self.features = features
        self.kernel_size = kernel_size
        self.h = h

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'features': self.features,
            'kernel_size': self.kernel_size,
            'h': self.h,
        })
        return config

    def build(self, input_shape):
        self.conv1ds = {k: InnerConv1DBlock(filters=self.features, h=self.h, kernel_size=self.kernel_size, name=k)
                        for k in ['psi', 'phi', 'eta', 'rho']}  # regularize?
        super().build(input_shape)
        # [layer.build(input_shape) for layer in self.conv1ds.values()]  # unneeded?

    def call(self, inputs, training=None):
        F_odd, F_even = inputs[:, ::2], inputs[:, 1::2]

        # Interactive learning as described in the paper
        F_s_odd = F_odd * tf.math.exp(self.conv1ds['phi'](F_even))
        F_s_even = F_even * tf.math.exp(self.conv1ds['psi'](F_odd))

        F_prime_odd = F_s_odd + self.conv1ds['rho'](F_s_even)
        F_prime_even = F_s_even - self.conv1ds['eta'](F_s_odd)

        return F_prime_odd, F_prime_even


class Interleave(tf.keras.layers.Layer):
    """A layer used to reverse the even-odd split operation."""

    def __init__(self, **kwargs):
        super(Interleave, self).__init__(**kwargs)

    def interleave(self, slices):
        if not slices:
            return slices
        elif len(slices) == 1:
            return slices[0]

        mid = len(slices) // 2
        even = self.interleave(slices[:mid])
        odd = self.interleave(slices[mid:])

        shape = tf.shape(even)
        return tf.reshape(tf.stack([even, odd], axis=3), (shape[0], shape[1] * 2, shape[2]))

    def call(self, inputs):
        return self.interleave(inputs)


class SciNet(tf.keras.layers.Layer):
    def __init__(self, horizon: int, features: int, levels: int, h: int, kernel_size: int,
                 regularizer: Tuple[float, float] = (0, 0), **kwargs):
        """
        :param horizon: number of time stamps in output
        :param features: number of features in output
        :param levels: height of the binary tree + 1
        :param h: scaling factor for convolutional module in each SciBlock
        :param kernel_size: kernel size of convolutional module in each SciBlock
        :param regularizer: activity regularization (not implemented)
        """

        if levels < 1:
            raise ValueError('Must have at least 1 level')
        super(SciNet, self).__init__(**kwargs)
        self.horizon = horizon
        self.features = features
        self.levels = levels
        self.interleave = Interleave()
        self.flatten = tf.keras.layers.Flatten()
        self.dense = tf.keras.layers.Dense(
            horizon * features,
            kernel_regularizer=L1L2(0.001, 0.01),
            # activity_regularizer=L1L2(0.001, 0.01)
        )
        # self.regularizer = tf.keras.layers.ActivityRegularization(l1=regularizer[0], l2=regularizer[1])

        # tree of sciblocks
        self.sciblocks = [SciBlock(features=features, kernel_size=kernel_size, h=h)
                          for _ in range(2 ** levels - 1)]

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'horizon': self.horizon,
            'features': self.features,
            'levels': self.levels,
            'interleave': self.interleave,
            'flatten': self.flatten,
            'dense': self.dense,
            'sciblocks': self.sciblocks,
        })
        return config

    def build(self, input_shape):
        if input_shape[1] / 2 ** self.levels % 1 != 0:
            raise ValueError(f'timestamps {input_shape[1]} must be evenly divisible by a tree with '
                             f'{self.levels} levels')
        super().build(input_shape)
        # [layer.build(input_shape) for layer in self.sciblocks]  # input_shape

    def call(self, inputs, training=None):
        # cascade input down a binary tree of sci-blocks
        lvl_inputs = [inputs]  # inputs for current level of the tree
        for i in range(self.levels):
            i_end = 2 ** (i + 1) - 1
            i_start = i_end - 2 ** i
            lvl_outputs = [output for j, tensor in zip(range(i_start, i_end), lvl_inputs)
                           for output in self.sciblocks[j](tensor)]
            lvl_inputs = lvl_outputs

        x = self.interleave(lvl_outputs)
        x += inputs

        # not sure if this is the correct way of doing it. The paper merely said to use a fully connected layer to
        # produce an output. Can't use TimeDistributed wrapper. It would force the layer's timestamps to match that of
        # the input -- something SCINet is supposed to solve
        x = self.flatten(x)
        x = self.dense(x)
        x = tf.reshape(x, (-1, self.horizon, self.features))

        return x


class StackedSciNet(tf.keras.layers.Layer):
    def __init__(self, horizon: int, features: int, stacks: int, levels: int, h: int, kernel_size: int,
                 regularizer: Tuple[float, float] = (0, 0), **kwargs):
        """
        :param horizon: number of time stamps in output
        :param stacks: number of stacked SciNets
        :param levels: number of levels for each SciNet
        :param h: scaling factor for convolutional module in each SciBlock
        :param kernel_size: kernel size of convolutional module in each SciBlock
        :param regularizer: activity regularization (not implemented)
        """

        if stacks < 1:
            raise ValueError('Must have at least 1 stack')
        super(StackedSciNet, self).__init__(**kwargs)
        self.horizon = horizon
        self.features = features
        self.stacks = stacks
        self.levels = levels
        self.h = h
        self.kernel_size = kernel_size
        self.regularizer = regularizer
        self.scinets = [SciNet(horizon=horizon, features=features, levels=levels, h=h, kernel_size=kernel_size,
                               regularizer=regularizer) for _ in range(stacks)]
        self.mse_fn = tf.keras.metrics.MeanSquaredError()
        self.mae_fn = tf.keras.metrics.MeanAbsoluteError()

    # def build(self, input_shape):
    #     super().build(input_shape)
    #     [stack.build(input_shape) for stack in self.scinets]

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'horizon': self.horizon,
            'features': self.features,
            'stacks': self.stacks,
            'levels': self.levels,
            'h': self.h,
            'kernel_size': self.kernel_size,
            'regularizer': self.regularizer,
        })
        return config

    def call(self, inputs, targets=None, sample_weights=None, training=None):
        outputs = []
        for scinet in self.scinets:
            x = scinet(inputs)
            outputs.append(x)  # keep each stack's output for intermediate supervision
            inputs = tf.concat([x, inputs[:, x.shape[1]:, :]], axis=1)

        if targets is not None:
            # Calculate metrics
            mse = self.mse_fn(targets, x, sample_weights)
            mae = self.mae_fn(targets, x, sample_weights)
            self.add_metric(mse, name='mean_squared_error')
            self.add_metric(mae, name='mean_absolute_error')

            if training:
                # Calculate loss as sum of mean of norms of differences between output and input feature vectors for
                # each stack
                stacked_outputs = tf.stack(outputs)
                differences = stacked_outputs - targets
                loss = tf.linalg.normalize(differences, axis=1)[1]
                loss = tf.reshape(loss, (-1, self.horizon))
                loss = tf.reduce_sum(loss, 1)
                loss = loss / self.horizon
                loss = tf.reduce_sum(loss)
                self.add_loss(loss)

        return x

# %%
model = tfk.models.load_model('SciNet_30V1.h5', custom_objects={"StackedSciNet": StackedSciNet, "MeanSquaredError" : tf.keras.metrics.MeanSquaredError, "MeanAbsoluteError" : tf.keras.metrics.MeanAbsoluteError, })

# %%
window = 720
pred_telescope = 576
pred_stride = 4

# %%
predicted = np.array([])
real = np.array([])
placeholder = np.empty([pred_telescope, 7])
placeholder = np.expand_dims(placeholder, axis=0)
total = ((len(X_train_raw)-pred_telescope-window) - 20000)/pred_stride
print(total)
for i in range(20000,(len(X_train_raw)-pred_telescope-window),pred_stride):
  X_temp = np.expand_dims(X_train_raw[i:i+window], axis=0)
  pred_temp = model.predict({'inputs': X_temp, 'targets': placeholder})
  y_temp = np.expand_dims(X_train_raw[i+window:i+window+pred_telescope], axis=0)
  if(len(predicted)==0):
    predicted = pred_temp
    real = y_temp
  else:
    predicted = np.concatenate((predicted,pred_temp),axis=0)
    real = np.concatenate((real,y_temp),axis=0)
# Out:
# 11558.0

# %%
predicted.shape, real.shape
# Out:
# ((11558, 576, 7), (11558, 576, 7))

# %%
predicted_reshaped = predicted.reshape(predicted.shape[0], -1)

# %%
np.savetxt("predicted_reshaped.csv", predicted_reshaped)

# %%
window = 576

# %%
target_labels = dataset.columns
telescope = 576

# %%
train_samples = 10000

# %%
X_train, y_train = predicted[:train_samples], real[:train_samples]

X_validation, y_validation = predicted[train_samples:], real[train_samples:]

X_train.shape, y_train.shape, X_validation.shape, y_validation.shape
# Out:
# ((10000, 576, 7), (10000, 576, 7), (1558, 576, 7), (1558, 576, 7))

# %%
inspect_multivariate(X_train, y_train, target_labels, telescope)

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
batch_size = 64
epochs = 200

# %%
def make_model(input_shape, output_shape):
    inputs = tf.keras.Input(shape=(window, 7), name='inputs')
    # x = SciNet(horizon, levels=L, h=h, kernel_size=kernel_size)(inputs)
    # model = tf.keras.Model(inputs, x)
    targets = tf.keras.Input(shape=(telescope, 7), name='targets')
    predictions = StackedSciNet(horizon=telescope, features=input_shape[-1], stacks=1, levels=4, h=4,
                                kernel_size=5,
                                regularizer=(1e-3, 0.1))(inputs, targets)
    model = tf.keras.Model(inputs=[inputs, targets], outputs=predictions)

    model.summary()
    tf.keras.utils.plot_model(model, to_file='modelDiagram.png', show_shapes=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss='mse',
                  metrics=['mean_squared_error', 'mean_absolute_error'])
    return model

# %%
model = make_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, 576, 7)]     0           []
#
#  targets (InputLayer)           [(None, 576, 7)]     0           []
#
#  stacked_sci_net (StackedSciNet  (None, 576, 7)      16380756    ['inputs[0][0]',
#  )                                                                'targets[0][0]']
#
# ==================================================================================================
# Total params: 16,380,756
# Trainable params: 16,380,756
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, 576, 7)]     0           []
#
#  targets (InputLayer)           [(None, 576, 7)]     0           []
#
#  stacked_sci_net (StackedSciNet  (None, 576, 7)      16380756    ['inputs[0][0]',
#  )                                                                'targets[0][0]']
#
# ==================================================================================================
# Total params: 16,380,756
# Trainable params: 16,380,756
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = {'inputs': X_train, 'targets': y_train},
    y = y_train,
    validation_data={'inputs': X_validation, 'targets': y_validation},
    batch_size = batch_size,
    epochs = epochs,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-6)
    ]
).history
# Out:
# Epoch 1/200
# 157/157 [==============================] - 24s 73ms/step - loss: 256.1402 - mean_squared_error: 0.8049 - mean_absolute_error: 0.5702 - val_loss: 162.7983 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.1022 - lr: 1.0000e-04
# Epoch 2/200
# 157/157 [==============================] - 9s 59ms/step - loss: 126.6615 - mean_squared_error: 0.0293 - mean_absolute_error: 0.1311 - val_loss: 76.8779 - val_mean_squared_error: 0.0116 - val_mean_absolute_error: 0.0808 - lr: 1.0000e-04
# Epoch 3/200
# 157/157 [==============================] - 9s 58ms/step - loss: 55.8779 - mean_squared_error: 0.0111 - mean_absolute_error: 0.0795 - val_loss: 29.0175 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0784 - lr: 1.0000e-04
# Epoch 4/200
# 157/157 [==============================] - 9s 59ms/step - loss: 23.2693 - mean_squared_error: 0.0093 - mean_absolute_error: 0.0716 - val_loss: 10.0838 - val_mean_squared_error: 0.0123 - val_mean_absolute_error: 0.0839 - lr: 1.0000e-04
# Epoch 5/200
# 157/157 [==============================] - 9s 58ms/step - loss: 11.8660 - mean_squared_error: 0.0089 - mean_absolute_error: 0.0698 - val_loss: 4.3651 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0828 - lr: 1.0000e-04
# Epoch 6/200
# 157/157 [==============================] - 9s 59ms/step - loss: 8.4151 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0683 - val_loss: 2.5485 - val_mean_squared_error: 0.0120 - val_mean_absolute_error: 0.0823 - lr: 1.0000e-04
# Epoch 7/200
# 157/157 [==============================] - 9s 59ms/step - loss: 7.1458 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0676 - val_loss: 1.7978 - val_mean_squared_error: 0.0109 - val_mean_absolute_error: 0.0787 - lr: 1.0000e-04
# Epoch 8/200
# 157/157 [==============================] - 9s 59ms/step - loss: 6.5516 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0671 - val_loss: 1.3820 - val_mean_squared_error: 0.0107 - val_mean_absolute_error: 0.0779 - lr: 1.0000e-04
# Epoch 9/200
# 157/157 [==============================] - 9s 59ms/step - loss: 6.2093 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0667 - val_loss: 1.1270 - val_mean_squared_error: 0.0105 - val_mean_absolute_error: 0.0780 - lr: 1.0000e-04
# Epoch 10/200
# 157/157 [==============================] - 9s 60ms/step - loss: 5.9947 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0664 - val_loss: 0.9963 - val_mean_squared_error: 0.0106 - val_mean_absolute_error: 0.0779 - lr: 1.0000e-04
# Epoch 11/200
# 157/157 [==============================] - 9s 59ms/step - loss: 5.8320 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0657 - val_loss: 0.8978 - val_mean_squared_error: 0.0101 - val_mean_absolute_error: 0.0757 - lr: 1.0000e-04
# Epoch 12/200
# 157/157 [==============================] - 9s 60ms/step - loss: 5.7170 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0648 - val_loss: 0.8517 - val_mean_squared_error: 0.0101 - val_mean_absolute_error: 0.0758 - lr: 1.0000e-04
# Epoch 13/200
# 157/157 [==============================] - 9s 58ms/step - loss: 5.6572 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0644 - val_loss: 0.8314 - val_mean_squared_error: 0.0100 - val_mean_absolute_error: 0.0764 - lr: 1.0000e-04
# Epoch 14/200
# 157/157 [==============================] - 9s 58ms/step - loss: 5.6058 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0639 - val_loss: 0.8141 - val_mean_squared_error: 0.0100 - val_mean_absolute_error: 0.0759 - lr: 1.0000e-04
# Epoch 15/200
# 157/157 [==============================] - 9s 59ms/step - loss: 5.5612 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0633 - val_loss: 0.8029 - val_mean_squared_error: 0.0102 - val_mean_absolute_error: 0.0761 - lr: 1.0000e-04
# Epoch 16/200
# 157/157 [==============================] - 9s 59ms/step - loss: 5.5474 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0632 - val_loss: 0.7867 - val_mean_squared_error: 0.0100 - val_mean_absolute_error: 0.0751 - lr: 1.0000e-04
# Epoch 17/200
# 157/157 [==============================] - 9s 59ms/step - loss: 5.5158 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0627 - val_loss: 0.7811 - val_mean_squared_error: 0.0096 - val_mean_absolute_error: 0.0736 - lr: 1.0000e-04
# Epoch 18/200
# 157/157 [==============================] - 9s 58ms/step - loss: 5.4872 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0624 - val_loss: 0.7834 - val_mean_squared_error: 0.0100 - val_mean_absolute_error: 0.0748 - lr: 1.0000e-04
# Epoch 19/200
# 157/157 [==============================] - 9s 60ms/step - loss: 5.4871 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0623 - val_loss: 0.7928 - val_mean_squared_error: 0.0096 - val_mean_absolute_error: 0.0742 - lr: 1.0000e-04
# Epoch 20/200
# 157/157 [==============================] - 9s 58ms/step - loss: 5.4694 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0620 - val_loss: 0.7845 - val_mean_squared_error: 0.0098 - val_mean_absolute_error: 0.0738 - lr: 1.0000e-04
# Epoch 21/200
# 157/157 [==============================] - 9s 58ms/step - loss: 5.4588 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0618 - val_loss: 0.7812 - val_mean_squared_error: 0.0097 - val_mean_absolute_error: 0.0730 - lr: 1.0000e-04
# Epoch 22/200
# 157/157 [==============================] - 9s 58ms/step - loss: 5.4419 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0615 - val_loss: 0.7938 - val_mean_squared_error: 0.0097 - val_mean_absolute_error: 0.0732 - lr: 1.0000e-04
# Epoch 23/200
# 157/157 [==============================] - 9s 59ms/step - loss: 5.1505 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0603 - val_loss: 0.5456 - val_mean_squared_error: 0.0095 - val_mean_absolute_error: 0.0723 - lr: 5.0000e-05
# Epoch 24/200
# 157/157 [==============================] - 9s 58ms/step - loss: 5.1260 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0602 - val_loss: 0.5468 - val_mean_squared_error: 0.0095 - val_mean_absolute_error: 0.0727 - lr: 5.0000e-05
# Epoch 25/200
# 157/157 [==============================] - 9s 60ms/step - loss: 5.1322 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0603 - val_loss: 0.5459 - val_mean_squared_error: 0.0095 - val_mean_absolute_error: 0.0728 - lr: 5.0000e-05
# Epoch 26/200
# 157/157 [==============================] - 9s 58ms/step - loss: 5.1278 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0602 - val_loss: 0.5506 - val_mean_squared_error: 0.0093 - val_mean_absolute_error: 0.0726 - lr: 5.0000e-05
# Epoch 27/200
# 157/157 [==============================] - 9s 58ms/step - loss: 5.1321 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0602 - val_loss: 0.5556 - val_mean_squared_error: 0.0095 - val_mean_absolute_error: 0.0730 - lr: 5.0000e-05
# Epoch 28/200
# 157/157 [==============================] - 9s 58ms/step - loss: 5.1234 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0599 - val_loss: 0.5577 - val_mean_squared_error: 0.0093 - val_mean_absolute_error: 0.0720 - lr: 5.0000e-05
# Epoch 29/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.9419 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0592 - val_loss: 0.4098 - val_mean_squared_error: 0.0093 - val_mean_absolute_error: 0.0720 - lr: 2.5000e-05
# Epoch 30/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.9315 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0592 - val_loss: 0.4080 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0704 - lr: 2.5000e-05
# Epoch 31/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.9337 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0592 - val_loss: 0.4064 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0704 - lr: 2.5000e-05
# Epoch 32/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.9250 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0591 - val_loss: 0.4089 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0704 - lr: 2.5000e-05
# Epoch 33/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.9309 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0591 - val_loss: 0.4093 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0714 - lr: 2.5000e-05
# Epoch 34/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.9192 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0589 - val_loss: 0.4092 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0703 - lr: 2.5000e-05
# Epoch 35/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.9206 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0590 - val_loss: 0.4104 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0706 - lr: 2.5000e-05
# Epoch 36/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.9176 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0589 - val_loss: 0.4044 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0707 - lr: 2.5000e-05
# Epoch 37/200
# 157/157 [==============================] - 9s 58ms/step - loss: 4.9118 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0588 - val_loss: 0.4048 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0703 - lr: 2.5000e-05
# Epoch 38/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.9097 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0588 - val_loss: 0.4020 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0701 - lr: 2.5000e-05
# Epoch 39/200
# 157/157 [==============================] - 9s 58ms/step - loss: 4.9011 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0587 - val_loss: 0.4065 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0702 - lr: 2.5000e-05
# Epoch 40/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.9021 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0587 - val_loss: 0.4009 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0702 - lr: 2.5000e-05
# Epoch 41/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.9005 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0587 - val_loss: 0.4014 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0702 - lr: 2.5000e-05
# Epoch 42/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8916 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0586 - val_loss: 0.4038 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0703 - lr: 2.5000e-05
# Epoch 43/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8931 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0586 - val_loss: 0.4010 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0701 - lr: 2.5000e-05
# Epoch 44/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8834 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0585 - val_loss: 0.3947 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0705 - lr: 2.5000e-05
# Epoch 45/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.8845 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0585 - val_loss: 0.3979 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0702 - lr: 2.5000e-05
# Epoch 46/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.8851 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0586 - val_loss: 0.3982 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0699 - lr: 2.5000e-05
# Epoch 47/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.8759 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0584 - val_loss: 0.3901 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0700 - lr: 2.5000e-05
# Epoch 48/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8710 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0584 - val_loss: 0.3930 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0702 - lr: 2.5000e-05
# Epoch 49/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.8675 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0583 - val_loss: 0.3909 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0702 - lr: 2.5000e-05
# Epoch 50/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8671 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0583 - val_loss: 0.3931 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0702 - lr: 2.5000e-05
# Epoch 51/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8616 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0582 - val_loss: 0.3896 - val_mean_squared_error: 0.0092 - val_mean_absolute_error: 0.0706 - lr: 2.5000e-05
# Epoch 52/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.8583 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0582 - val_loss: 0.3858 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0700 - lr: 2.5000e-05
# Epoch 53/200
# 157/157 [==============================] - 9s 61ms/step - loss: 4.8535 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0582 - val_loss: 0.3876 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0697 - lr: 2.5000e-05
# Epoch 54/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.8493 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0581 - val_loss: 0.3839 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0701 - lr: 2.5000e-05
# Epoch 55/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8506 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0581 - val_loss: 0.3901 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0696 - lr: 2.5000e-05
# Epoch 56/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8438 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0580 - val_loss: 0.3849 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0697 - lr: 2.5000e-05
# Epoch 57/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.8400 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0580 - val_loss: 0.3877 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0694 - lr: 2.5000e-05
# Epoch 58/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.8457 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0580 - val_loss: 0.3832 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0700 - lr: 2.5000e-05
# Epoch 59/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.8378 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0580 - val_loss: 0.3852 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0701 - lr: 2.5000e-05
# Epoch 60/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8361 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0579 - val_loss: 0.3862 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0700 - lr: 2.5000e-05
# Epoch 61/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8339 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0579 - val_loss: 0.3841 - val_mean_squared_error: 0.0091 - val_mean_absolute_error: 0.0701 - lr: 2.5000e-05
# Epoch 62/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8309 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0579 - val_loss: 0.3852 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0699 - lr: 2.5000e-05
# Epoch 63/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.8295 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0578 - val_loss: 0.3860 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0705 - lr: 2.5000e-05
# Epoch 64/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.7131 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0573 - val_loss: 0.2929 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0697 - lr: 1.2500e-05
# Epoch 65/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.6999 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.2926 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0692 - lr: 1.2500e-05
# Epoch 66/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.7027 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.2938 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0691 - lr: 1.2500e-05
# Epoch 67/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.7013 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.2935 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0694 - lr: 1.2500e-05
# Epoch 68/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.6988 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.2911 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0693 - lr: 1.2500e-05
# Epoch 69/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.6999 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.2904 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0695 - lr: 1.2500e-05
# Epoch 70/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.6949 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.2923 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0693 - lr: 1.2500e-05
# Epoch 71/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.6973 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.2905 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0697 - lr: 1.2500e-05
# Epoch 72/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.6949 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.2890 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0695 - lr: 1.2500e-05
# Epoch 73/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.6932 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.2911 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0695 - lr: 1.2500e-05
# Epoch 74/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.6912 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.2889 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0692 - lr: 1.2500e-05
# Epoch 75/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.6855 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0571 - val_loss: 0.2902 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0693 - lr: 1.2500e-05
# Epoch 76/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.6843 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0571 - val_loss: 0.2885 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0694 - lr: 1.2500e-05
# Epoch 77/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.6832 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0570 - val_loss: 0.2866 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0692 - lr: 1.2500e-05
# Epoch 78/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.6836 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0571 - val_loss: 0.2899 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0697 - lr: 1.2500e-05
# Epoch 79/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.6819 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0570 - val_loss: 0.2878 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0694 - lr: 1.2500e-05
# Epoch 80/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.6795 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0570 - val_loss: 0.2880 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0700 - lr: 1.2500e-05
# Epoch 81/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.6775 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0570 - val_loss: 0.2873 - val_mean_squared_error: 0.0090 - val_mean_absolute_error: 0.0691 - lr: 1.2500e-05
# Epoch 82/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.6785 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0570 - val_loss: 0.2867 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0692 - lr: 1.2500e-05
# Epoch 83/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.6086 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2358 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0688 - lr: 6.2500e-06
# Epoch 84/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.6063 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2355 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0688 - lr: 6.2500e-06
# Epoch 85/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.6068 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2366 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0690 - lr: 6.2500e-06
# Epoch 86/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.6037 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2347 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0688 - lr: 6.2500e-06
# Epoch 87/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.6013 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2345 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0690 - lr: 6.2500e-06
# Epoch 88/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.6029 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2346 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0691 - lr: 6.2500e-06
# Epoch 89/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.5991 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2355 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0690 - lr: 6.2500e-06
# Epoch 90/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.6003 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2335 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0687 - lr: 6.2500e-06
# Epoch 91/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5999 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2336 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0690 - lr: 6.2500e-06
# Epoch 92/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.5994 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2351 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0691 - lr: 6.2500e-06
# Epoch 93/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5989 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2330 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0689 - lr: 6.2500e-06
# Epoch 94/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5989 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.2335 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0690 - lr: 6.2500e-06
# Epoch 95/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5947 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0565 - val_loss: 0.2346 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0689 - lr: 6.2500e-06
# Epoch 96/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.5940 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0565 - val_loss: 0.2334 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0689 - lr: 6.2500e-06
# Epoch 97/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5936 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0565 - val_loss: 0.2327 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0689 - lr: 6.2500e-06
# Epoch 98/200
# 157/157 [==============================] - 9s 61ms/step - loss: 4.5914 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0565 - val_loss: 0.2309 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0689 - lr: 6.2500e-06
# Epoch 99/200
# 157/157 [==============================] - 13s 86ms/step - loss: 4.5926 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0565 - val_loss: 0.2320 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0687 - lr: 6.2500e-06
# Epoch 100/200
# 157/157 [==============================] - 13s 81ms/step - loss: 4.5907 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0565 - val_loss: 0.2313 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0687 - lr: 6.2500e-06
# Epoch 101/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5918 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0565 - val_loss: 0.2313 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0690 - lr: 6.2500e-06
# Epoch 102/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5909 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0565 - val_loss: 0.2319 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0689 - lr: 6.2500e-06
# Epoch 103/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.5894 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0565 - val_loss: 0.2311 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0689 - lr: 6.2500e-06
# Epoch 104/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5533 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0563 - val_loss: 0.2037 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0688 - lr: 3.1250e-06
# Epoch 105/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5498 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0563 - val_loss: 0.2035 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0688 - lr: 3.1250e-06
# Epoch 106/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5479 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0563 - val_loss: 0.2035 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0686 - lr: 3.1250e-06
# Epoch 107/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5479 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0563 - val_loss: 0.2031 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0686 - lr: 3.1250e-06
# Epoch 108/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5467 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0563 - val_loss: 0.2023 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0685 - lr: 3.1250e-06
# Epoch 109/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5457 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2018 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0686 - lr: 3.1250e-06
# Epoch 110/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.5479 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0563 - val_loss: 0.2019 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0687 - lr: 3.1250e-06
# Epoch 111/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5477 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0563 - val_loss: 0.2023 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0687 - lr: 3.1250e-06
# Epoch 112/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5499 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0563 - val_loss: 0.2018 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0689 - lr: 3.1250e-06
# Epoch 113/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.5467 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2021 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0687 - lr: 3.1250e-06
# Epoch 114/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5465 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2016 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0689 - lr: 3.1250e-06
# Epoch 115/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5452 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2020 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0687 - lr: 3.1250e-06
# Epoch 116/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.5436 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2016 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0685 - lr: 3.1250e-06
# Epoch 117/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5463 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0563 - val_loss: 0.2015 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0686 - lr: 3.1250e-06
# Epoch 118/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5454 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2012 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0687 - lr: 3.1250e-06
# Epoch 119/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5451 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2020 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0687 - lr: 3.1250e-06
# Epoch 120/200
# 157/157 [==============================] - 9s 59ms/step - loss: 4.5432 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2022 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0690 - lr: 3.1250e-06
# Epoch 121/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.5414 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2014 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0687 - lr: 3.1250e-06
# Epoch 122/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.5424 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2009 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0685 - lr: 3.1250e-06
# Epoch 123/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5389 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2008 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0690 - lr: 3.1250e-06
# Epoch 124/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5398 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2002 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0688 - lr: 3.1250e-06
# Epoch 125/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.5408 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2006 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0689 - lr: 3.1250e-06
# Epoch 126/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5409 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2001 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0686 - lr: 3.1250e-06
# Epoch 127/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5391 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2002 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0687 - lr: 3.1250e-06
# Epoch 128/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5396 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.1993 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0688 - lr: 3.1250e-06
# Epoch 129/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5360 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0561 - val_loss: 0.2004 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0688 - lr: 3.1250e-06
# Epoch 130/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.5391 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.1999 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0688 - lr: 3.1250e-06
# Epoch 131/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5376 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0561 - val_loss: 0.2001 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0686 - lr: 3.1250e-06
# Epoch 132/200
# 157/157 [==============================] - 9s 60ms/step - loss: 4.5361 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - val_loss: 0.2003 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0687 - lr: 3.1250e-06
# Epoch 133/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5365 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0561 - val_loss: 0.2002 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0685 - lr: 3.1250e-06
# Epoch 134/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5150 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0560 - val_loss: 0.1846 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0684 - lr: 1.5625e-06
# Epoch 135/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5154 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0560 - val_loss: 0.1843 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0687 - lr: 1.5625e-06
# Epoch 136/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5156 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0561 - val_loss: 0.1841 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0686 - lr: 1.5625e-06
# Epoch 137/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5149 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0560 - val_loss: 0.1839 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0685 - lr: 1.5625e-06
# Epoch 138/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.5129 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0560 - val_loss: 0.1839 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0686 - lr: 1.5625e-06
# Epoch 139/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.5143 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0561 - val_loss: 0.1837 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0685 - lr: 1.5625e-06
# Epoch 140/200
# 157/157 [==============================] - 10s 61ms/step - loss: 4.5147 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0560 - val_loss: 0.1837 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0686 - lr: 1.5625e-06
# Epoch 141/200
# 157/157 [==============================] - 10s 62ms/step - loss: 4.5155 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0560 - val_loss: 0.1837 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0687 - lr: 1.5625e-06
# Epoch 142/200
#  47/157 [=======>......................] - ETA: 6s - loss: 4.5076 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0559
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-e792b695c379> in <module>()
#       8     callbacks = [
#       9         tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
# ---> 10         tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-6)
#      11     ]
#      12 ).history
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
# -> 3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#    3133   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958       # No tape is watching; skip to running the function.
#    1959       return self._build_call_outputs(self._inference_function.call(
# -> 1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#    1962         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     601               inputs=args,
#     602               attrs=attrs,
# --> 603               ctx=ctx)
#     604         else:
#     605           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# KeyboardInterrupt:

# %%
model.save('SciNet_optimizer2.h5')
