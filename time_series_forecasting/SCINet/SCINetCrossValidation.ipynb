# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/ANN/CH2/Tests
# Out:
# /gdrive/My Drive/ANN/CH2/Tests

# %% [markdown]
# ### Import libraries

# %%
import tensorflow as tf
import numpy as np
import os
import math
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
plt.rc('font', size=16)
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

from sklearn.model_selection import KFold

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %% [markdown]
# # Initial Setup

# %%
# Random seed for reproducibility
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset = pd.read_csv('Training.csv')
print(dataset.shape)
dataset.head()
# Out:
# (68528, 7)
#    Sponginess  Wonder level  ...  Soap slipperiness  Hype root
# 0     7.97698       4.33494  ...          51.681460    3.65434
# 1     8.07824       4.44616  ...          51.563598    3.47672
# 2     8.02844       4.22372  ...          50.863080    3.47672
# 3     8.02844       4.22372  ...          45.841581    3.47672
# 4     7.87572       4.44616  ...          47.126421    3.47672
#
# [5 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68528 entries, 0 to 68527
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sponginess          68528 non-null  float64
#  1   Wonder level        68528 non-null  float64
#  2   Crunchiness         68528 non-null  float64
#  3   Loudness on impact  68528 non-null  float64
#  4   Meme creativity     68528 non-null  float64
#  5   Soap slipperiness   68528 non-null  float64
#  6   Hype root           68528 non-null  float64
# dtypes: float64(7)
# memory usage: 3.7 MB

# %%
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
inspect_dataframe(dataset, dataset.columns)

# %% [markdown]
# Sequential Train-Test split and normalization

# %%
# Normalize both features and labels
X_min = dataset.min()
X_max = dataset.max()

X_train_raw = (dataset-X_min)/(X_max-X_min)

plt.figure(figsize=(17,5))
plt.plot(X_train_raw.Sponginess, label='Train (Sponginess)')
plt.title('Normalized')
plt.legend()
plt.show()

# %%
def build_sequences(df, target_labels=['pollution'], window=200, stride=20, telescope=100):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float64')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float64')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %% [markdown]
# # V 3.0

# %% [markdown]
# ### SciNet - W 720 - S 1 - T 16 #6

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
window = 720
stride = 1

# %% [markdown]
# SciNet Implementation is an adaptation of open repository: https://github.com/Meatssauce/SCINet

# %%
from typing import Tuple
import tensorflow as tf
from tensorflow.keras.regularizers import L1L2


class InnerConv1DBlock(tf.keras.layers.Layer):
    def __init__(self, filters: int, h: float, kernel_size: int, neg_slope: float = .01, dropout: float = .5, **kwargs):
        if filters <= 0 or h <= 0:
            raise ValueError('filters and h must be positive')
        super(InnerConv1DBlock, self).__init__(**kwargs)
        self.conv1d = tf.keras.layers.Conv1D(max(round(h * filters), 1), kernel_size, padding='same')
        self.leakyrelu = tf.keras.layers.LeakyReLU(neg_slope)

        self.dropout = tf.keras.layers.Dropout(dropout)

        self.conv1d2 = tf.keras.layers.Conv1D(filters, kernel_size, padding='same')
        self.tanh = tf.keras.activations.tanh

    def call(self, input_tensor, training=None):
        x = self.conv1d(input_tensor)
        x = self.leakyrelu(x)

        if training:
            x = self.dropout(x)

        x = self.conv1d2(x)
        x = self.tanh(x)
        return x


class SciBlock(tf.keras.layers.Layer):
    def __init__(self, features: int, kernel_size: int, h: int, **kwargs):
        """
        :param features: number of features in the output
        :param kernel_size: kernel size of the convolutional layers
        :param h: scaling factor for convolutional module
        """

        super(SciBlock, self).__init__(**kwargs)
        self.features = features
        self.kernel_size = kernel_size
        self.h = h

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'features': self.features,
            'kernel_size': self.kernel_size,
            'h': self.h,
        })
        return config

    def build(self, input_shape):
        self.conv1ds = {k: InnerConv1DBlock(filters=self.features, h=self.h, kernel_size=self.kernel_size, name=k)
                        for k in ['psi', 'phi', 'eta', 'rho']}  # regularize?
        super().build(input_shape)
        # [layer.build(input_shape) for layer in self.conv1ds.values()]  # unneeded?

    def call(self, inputs, training=None):
        F_odd, F_even = inputs[:, ::2], inputs[:, 1::2]

        # Interactive learning as described in the paper
        F_s_odd = F_odd * tf.math.exp(self.conv1ds['phi'](F_even))
        F_s_even = F_even * tf.math.exp(self.conv1ds['psi'](F_odd))

        F_prime_odd = F_s_odd + self.conv1ds['rho'](F_s_even)
        F_prime_even = F_s_even - self.conv1ds['eta'](F_s_odd)

        return F_prime_odd, F_prime_even


class Interleave(tf.keras.layers.Layer):
    """A layer used to reverse the even-odd split operation."""

    def __init__(self, **kwargs):
        super(Interleave, self).__init__(**kwargs)

    def interleave(self, slices):
        if not slices:
            return slices
        elif len(slices) == 1:
            return slices[0]

        mid = len(slices) // 2
        even = self.interleave(slices[:mid])
        odd = self.interleave(slices[mid:])

        shape = tf.shape(even)
        return tf.reshape(tf.stack([even, odd], axis=3), (shape[0], shape[1] * 2, shape[2]))

    def call(self, inputs):
        return self.interleave(inputs)


class SciNet(tf.keras.layers.Layer):
    def __init__(self, horizon: int, features: int, levels: int, h: int, kernel_size: int,
                 regularizer: Tuple[float, float] = (0, 0), **kwargs):
        """
        :param horizon: number of time stamps in output
        :param features: number of features in output
        :param levels: height of the binary tree + 1
        :param h: scaling factor for convolutional module in each SciBlock
        :param kernel_size: kernel size of convolutional module in each SciBlock
        :param regularizer: activity regularization (not implemented)
        """

        if levels < 1:
            raise ValueError('Must have at least 1 level')
        super(SciNet, self).__init__(**kwargs)
        self.horizon = horizon
        self.features = features
        self.levels = levels
        self.interleave = Interleave()
        self.flatten = tf.keras.layers.Flatten()
        self.dense = tf.keras.layers.Dense(
            horizon * features,
            kernel_regularizer=L1L2(0.001, 0.01),
            # activity_regularizer=L1L2(0.001, 0.01)
        )
        # self.regularizer = tf.keras.layers.ActivityRegularization(l1=regularizer[0], l2=regularizer[1])

        # tree of sciblocks
        self.sciblocks = [SciBlock(features=features, kernel_size=kernel_size, h=h)
                          for _ in range(2 ** levels - 1)]

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'horizon': self.horizon,
            'features': self.features,
            'levels': self.levels,
            'interleave': self.interleave,
            'flatten': self.flatten,
            'dense': self.dense,
            'sciblocks': self.sciblocks,
        })
        return config

    def build(self, input_shape):
        if input_shape[1] / 2 ** self.levels % 1 != 0:
            raise ValueError(f'timestamps {input_shape[1]} must be evenly divisible by a tree with '
                             f'{self.levels} levels')
        super().build(input_shape)
        # [layer.build(input_shape) for layer in self.sciblocks]  # input_shape

    def call(self, inputs, training=None):
        # cascade input down a binary tree of sci-blocks
        lvl_inputs = [inputs]  # inputs for current level of the tree
        for i in range(self.levels):
            i_end = 2 ** (i + 1) - 1
            i_start = i_end - 2 ** i
            lvl_outputs = [output for j, tensor in zip(range(i_start, i_end), lvl_inputs)
                           for output in self.sciblocks[j](tensor)]
            lvl_inputs = lvl_outputs

        x = self.interleave(lvl_outputs)
        x += inputs

        # not sure if this is the correct way of doing it. The paper merely said to use a fully connected layer to
        # produce an output. Can't use TimeDistributed wrapper. It would force the layer's timestamps to match that of
        # the input -- something SCINet is supposed to solve
        x = self.flatten(x)
        x = self.dense(x)
        x = tf.reshape(x, (-1, self.horizon, self.features))

        return x


class StackedSciNet(tf.keras.layers.Layer):
    def __init__(self, horizon: int, features: int, stacks: int, levels: int, h: int, kernel_size: int,
                 regularizer: Tuple[float, float] = (0, 0), **kwargs):
        """
        :param horizon: number of time stamps in output
        :param stacks: number of stacked SciNets
        :param levels: number of levels for each SciNet
        :param h: scaling factor for convolutional module in each SciBlock
        :param kernel_size: kernel size of convolutional module in each SciBlock
        :param regularizer: activity regularization (not implemented)
        """

        if stacks < 1:
            raise ValueError('Must have at least 1 stack')
        super(StackedSciNet, self).__init__(**kwargs)
        self.horizon = horizon
        self.features = features
        self.stacks = stacks
        self.levels = levels
        self.h = h
        self.kernel_size = kernel_size
        self.regularizer = regularizer
        self.scinets = [SciNet(horizon=horizon, features=features, levels=levels, h=h, kernel_size=kernel_size,
                               regularizer=regularizer) for _ in range(stacks)]
        self.mse_fn = tf.keras.metrics.MeanSquaredError()
        self.mae_fn = tf.keras.metrics.MeanAbsoluteError()

    # def build(self, input_shape):
    #     super().build(input_shape)
    #     [stack.build(input_shape) for stack in self.scinets]

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'horizon': self.horizon,
            'features': self.features,
            'stacks': self.stacks,
            'levels': self.levels,
            'h': self.h,
            'kernel_size': self.kernel_size,
            'regularizer': self.regularizer,
        })
        return config

    def call(self, inputs, targets=None, sample_weights=None, training=None):
        outputs = []
        for scinet in self.scinets:
            x = scinet(inputs)
            outputs.append(x)  # keep each stack's output for intermediate supervision
            inputs = tf.concat([x, inputs[:, x.shape[1]:, :]], axis=1)

        if targets is not None:
            # Calculate metrics
            mse = self.mse_fn(targets, x, sample_weights)
            mae = self.mae_fn(targets, x, sample_weights)
            self.add_metric(mse, name='mean_squared_error')
            self.add_metric(mae, name='mean_absolute_error')

            if training:
                # Calculate loss as sum of mean of norms of differences between output and input feature vectors for
                # each stack
                stacked_outputs = tf.stack(outputs)
                differences = stacked_outputs - targets
                loss = tf.linalg.normalize(differences, axis=1)[1]
                loss = tf.reshape(loss, (-1, self.horizon))
                loss = tf.reduce_sum(loss, 1)
                loss = loss / self.horizon
                loss = tf.reduce_sum(loss)
                self.add_loss(loss)

        return x

# %%
target_labels = dataset.columns
telescope = 16

# %%
batch_size = 512
epochs = 160

# %%
def make_model(input_shape, output_shape):
    inputs = tf.keras.Input(shape=(window, 7), name='inputs')
    # x = SciNet(horizon, levels=L, h=h, kernel_size=kernel_size)(inputs)
    # model = tf.keras.Model(inputs, x)
    targets = tf.keras.Input(shape=(telescope, 7), name='targets')
    predictions = StackedSciNet(horizon=telescope, features=input_shape[-1], stacks=1, levels=4, h=4,
                                kernel_size=5,
                                regularizer=(1e-3, 0.1))(inputs, targets)
    model = tf.keras.Model(inputs=[inputs, targets], outputs=predictions)

    model.summary()
    tf.keras.utils.plot_model(model, to_file='modelDiagram.png', show_shapes=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse',
                  metrics=['mean_squared_error', 'mean_absolute_error'])
    return model

# %%
num_folds=10

single_interval = math.floor(len(X_train_raw)/num_folds)

intervals = []
current = 0
for i in range(num_folds):
  intervals.append(current)
  current += single_interval

intervals.append(len(X_train_raw) - 1)

print(len(X_train_raw))
print(intervals)
# Out:
# 68528
# [0, 6852, 13704, 20556, 27408, 34260, 41112, 47964, 54816, 61668, 68527]

# %%
# K-fold Cross Validation model evaluation
for fold in range(num_folds):
  print("starting.... fold "+str(fold+1))
  X_train = np.array([])
  y_train = np.array([])
  X_validation = np.array([])
  y_validation = np.array([])

  validation_raw = np.array([])

  #Create sequences from different folds
  for i in range(num_folds):
    data = X_train_raw[intervals[i]:intervals[i+1]]
    if (fold == i):
      X_validation, y_validation = build_sequences(data, target_labels, window, stride, telescope)
      validation_raw = data.copy()
    elif len(X_train) == 0:
      X_train, y_train = build_sequences(data, target_labels, window, stride, telescope)
    else:
      X_temp, y_temp = build_sequences(data, target_labels, window, stride, telescope)
      X_train = np.concatenate((X_train, X_temp), axis=0)
      y_train = np.concatenate((y_train, y_temp), axis=0)

  input_shape = X_train.shape[1:]
  output_shape = y_train.shape[1:]

  #BUILD THE MODEL
  with strategy.scope():
    model = make_model(input_shape, output_shape)

  history = model.fit(
    x = {'inputs': X_train, 'targets': y_train},
    y = y_train,
    validation_data={'inputs': X_validation, 'targets': y_validation},
    batch_size = batch_size,
    epochs = epochs,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_mean_absolute_error', mode='min', patience=20, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_mean_absolute_error', mode='min', patience=5, factor=0.5, min_lr=1e-8)
    ]
  ).history

  reg_telescope = 1200
  X_validation_reg, y_validation_reg = build_sequences(validation_raw, target_labels, window, stride, reg_telescope)

  reg_predictions = np.array([])
  X_temp = X_validation_reg
  placeholder = np.empty([len(X_temp),telescope, 7])
  for reg in range(0,reg_telescope,telescope):
      pred_temp = model.predict({'inputs': X_temp, 'targets': placeholder})
      if(len(reg_predictions)==0):
          reg_predictions = pred_temp
      else:
          reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
      X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)
  
  print(y_validation_reg.shape)
  print(reg_predictions.shape)

  mean_squared_error = tfk.metrics.mse(y_validation_reg.flatten(),reg_predictions.flatten())
  mean_absolute_error = tfk.metrics.mae(y_validation_reg.flatten(),reg_predictions.flatten())
  print(mean_squared_error, mean_absolute_error)
# Out:
# starting.... fold 1
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, 720, 7)]     0           []
#
#  targets (InputLayer)           [(None, 16, 7)]      0           []
#
#  stacked_sci_net_5 (StackedSciN  (None, 16, 7)       684292      ['inputs[0][0]',
#  et)                                                              'targets[0][0]']
#
# ==================================================================================================
# Total params: 684,292
# Trainable params: 684,292
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/160
# 114/114 [==============================] - 90s 307ms/step - loss: 32.9328 - mean_squared_error: 0.5217 - mean_absolute_error: 0.3154 - val_loss: 9.9830 - val_mean_squared_error: 0.0162 - val_mean_absolute_error: 0.0935 - lr: 0.0010
# Epoch 2/160
# 114/114 [==============================] - 7s 59ms/step - loss: 15.7033 - mean_squared_error: 0.0139 - mean_absolute_error: 0.0916 - val_loss: 8.8966 - val_mean_squared_error: 0.0147 - val_mean_absolute_error: 0.0855 - lr: 0.0010
# Epoch 3/160
# 114/114 [==============================] - 7s 60ms/step - loss: 13.9176 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0803 - val_loss: 7.9223 - val_mean_squared_error: 0.0125 - val_mean_absolute_error: 0.0822 - lr: 0.0010
# Epoch 4/160
# 114/114 [==============================] - 7s 60ms/step - loss: 12.4143 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0715 - val_loss: 6.9850 - val_mean_squared_error: 0.0106 - val_mean_absolute_error: 0.0756 - lr: 0.0010
# Epoch 5/160
# 114/114 [==============================] - 7s 60ms/step - loss: 10.9367 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0625 - val_loss: 6.0751 - val_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0631 - lr: 0.0010
# Epoch 6/160
# 114/114 [==============================] - 7s 62ms/step - loss: 9.6083 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0554 - val_loss: 5.2016 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0579 - lr: 0.0010
# Epoch 7/160
# 114/114 [==============================] - 7s 61ms/step - loss: 8.4967 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0512 - val_loss: 4.3766 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0508 - lr: 0.0010
# Epoch 8/160
# 114/114 [==============================] - 7s 59ms/step - loss: 7.4331 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0467 - val_loss: 3.6136 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0485 - lr: 0.0010
# Epoch 9/160
# 114/114 [==============================] - 7s 64ms/step - loss: 6.5334 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0438 - val_loss: 2.9313 - val_mean_squared_error: 0.0031 - val_mean_absolute_error: 0.0422 - lr: 0.0010
# Epoch 10/160
# 114/114 [==============================] - 6s 54ms/step - loss: 5.7645 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0417 - val_loss: 2.3380 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0430 - lr: 0.0010
# Epoch 11/160
# 114/114 [==============================] - 6s 54ms/step - loss: 5.1150 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0400 - val_loss: 1.8401 - val_mean_squared_error: 0.0031 - val_mean_absolute_error: 0.0425 - lr: 0.0010
# Epoch 12/160
# 114/114 [==============================] - 7s 60ms/step - loss: 4.5877 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0387 - val_loss: 1.4387 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0395 - lr: 0.0010
# Epoch 13/160
# 114/114 [==============================] - 7s 60ms/step - loss: 4.1796 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0378 - val_loss: 1.1230 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0386 - lr: 0.0010
# Epoch 14/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.8747 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0373 - val_loss: 0.8852 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0387 - lr: 0.0010
# Epoch 15/160
# 114/114 [==============================] - 7s 64ms/step - loss: 3.6522 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0370 - val_loss: 0.7121 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0379 - lr: 0.0010
# Epoch 16/160
# 114/114 [==============================] - 6s 55ms/step - loss: 3.4900 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0368 - val_loss: 0.5869 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0381 - lr: 0.0010
# Epoch 17/160
# 114/114 [==============================] - 7s 60ms/step - loss: 3.3826 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0367 - val_loss: 0.5064 - val_mean_squared_error: 0.0025 - val_mean_absolute_error: 0.0369 - lr: 0.0010
# Epoch 18/160
# 114/114 [==============================] - 6s 55ms/step - loss: 3.2893 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0363 - val_loss: 0.4516 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0376 - lr: 0.0010
# Epoch 19/160
# 114/114 [==============================] - 7s 60ms/step - loss: 3.2348 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0361 - val_loss: 0.4193 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0368 - lr: 0.0010
# Epoch 20/160
# 114/114 [==============================] - 6s 55ms/step - loss: 3.1985 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0359 - val_loss: 0.4007 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0377 - lr: 0.0010
# Epoch 21/160
# 114/114 [==============================] - 7s 60ms/step - loss: 3.1629 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0356 - val_loss: 0.3866 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0367 - lr: 0.0010
# Epoch 22/160
# 114/114 [==============================] - 6s 55ms/step - loss: 3.1589 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0357 - val_loss: 0.3820 - val_mean_squared_error: 0.0025 - val_mean_absolute_error: 0.0375 - lr: 0.0010
# Epoch 23/160
# 114/114 [==============================] - 7s 60ms/step - loss: 3.1552 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0357 - val_loss: 0.3793 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0358 - lr: 0.0010
# Epoch 24/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.1552 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0357 - val_loss: 0.3800 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0382 - lr: 0.0010
# Epoch 25/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.1390 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0355 - val_loss: 0.3759 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0376 - lr: 0.0010
# Epoch 26/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.1236 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0352 - val_loss: 0.3769 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0408 - lr: 0.0010
# Epoch 27/160
# 114/114 [==============================] - 6s 55ms/step - loss: 3.1278 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0354 - val_loss: 0.3817 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0412 - lr: 0.0010
# Epoch 28/160
# 114/114 [==============================] - 6s 55ms/step - loss: 3.1175 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0352 - val_loss: 0.3787 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0382 - lr: 0.0010
# Epoch 29/160
# 114/114 [==============================] - 7s 60ms/step - loss: 3.0395 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0342 - val_loss: 0.3482 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0346 - lr: 5.0000e-04
# Epoch 30/160
# 114/114 [==============================] - 7s 61ms/step - loss: 3.0302 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0341 - val_loss: 0.3476 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0346 - lr: 5.0000e-04
# Epoch 31/160
# 114/114 [==============================] - 6s 55ms/step - loss: 3.0274 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0341 - val_loss: 0.3454 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0386 - lr: 5.0000e-04
# Epoch 32/160
# 114/114 [==============================] - 6s 55ms/step - loss: 3.0289 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0342 - val_loss: 0.3463 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0353 - lr: 5.0000e-04
# Epoch 33/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.0332 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0342 - val_loss: 0.3468 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0362 - lr: 5.0000e-04
# Epoch 34/160
# 114/114 [==============================] - 6s 55ms/step - loss: 3.0221 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0340 - val_loss: 0.3507 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0379 - lr: 5.0000e-04
# Epoch 35/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.9793 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0335 - val_loss: 0.3271 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0364 - lr: 2.5000e-04
# Epoch 36/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.9734 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0335 - val_loss: 0.3271 - val_mean_squared_error: 0.0025 - val_mean_absolute_error: 0.0367 - lr: 2.5000e-04
# Epoch 37/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.9767 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0336 - val_loss: 0.3249 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0363 - lr: 2.5000e-04
# Epoch 38/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.9747 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0335 - val_loss: 0.3267 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0346 - lr: 2.5000e-04
# Epoch 39/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.9718 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0335 - val_loss: 0.3263 - val_mean_squared_error: 0.0025 - val_mean_absolute_error: 0.0359 - lr: 2.5000e-04
# Epoch 40/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.9430 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0332 - val_loss: 0.3122 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0355 - lr: 1.2500e-04
# Epoch 41/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.9405 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0332 - val_loss: 0.3119 - val_mean_squared_error: 0.0022 - val_mean_absolute_error: 0.0338 - lr: 1.2500e-04
# Epoch 42/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.9419 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0332 - val_loss: 0.3107 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0347 - lr: 1.2500e-04
# Epoch 43/160
# 114/114 [==============================] - 6s 56ms/step - loss: 2.9435 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0333 - val_loss: 0.3120 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0353 - lr: 1.2500e-04
# Epoch 44/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.9423 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0333 - val_loss: 0.3121 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0343 - lr: 1.2500e-04
# Epoch 45/160
# 114/114 [==============================] - 6s 54ms/step - loss: 2.9416 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0332 - val_loss: 0.3107 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0347 - lr: 1.2500e-04
# Epoch 46/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.9396 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0332 - val_loss: 0.3115 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0372 - lr: 1.2500e-04
# Epoch 47/160
# 114/114 [==============================] - 6s 54ms/step - loss: 2.9216 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0330 - val_loss: 0.3003 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0352 - lr: 6.2500e-05
# Epoch 48/160
# 114/114 [==============================] - 6s 54ms/step - loss: 2.9184 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0330 - val_loss: 0.3010 - val_mean_squared_error: 0.0025 - val_mean_absolute_error: 0.0355 - lr: 6.2500e-05
# Epoch 49/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.9192 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0330 - val_loss: 0.2994 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0344 - lr: 6.2500e-05
# Epoch 50/160
# 114/114 [==============================] - 6s 54ms/step - loss: 2.9170 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0330 - val_loss: 0.2999 - val_mean_squared_error: 0.0025 - val_mean_absolute_error: 0.0360 - lr: 6.2500e-05
# Epoch 51/160
# 114/114 [==============================] - 6s 56ms/step - loss: 2.9178 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0330 - val_loss: 0.3001 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0342 - lr: 6.2500e-05
# Epoch 52/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.9066 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0329 - val_loss: 0.2933 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0343 - lr: 3.1250e-05
# Epoch 53/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.9039 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0329 - val_loss: 0.2932 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0342 - lr: 3.1250e-05
# Epoch 54/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.9048 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0329 - val_loss: 0.2931 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0343 - lr: 3.1250e-05
# Epoch 55/160
# 114/114 [==============================] - 6s 56ms/step - loss: 2.9030 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0329 - val_loss: 0.2926 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0345 - lr: 3.1250e-05
# Epoch 56/160
# 114/114 [==============================] - 6s 56ms/step - loss: 2.9045 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0329 - val_loss: 0.2932 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0352 - lr: 3.1250e-05
# Epoch 57/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.8960 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2881 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0352 - lr: 1.5625e-05
# Epoch 58/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.8943 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2885 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0345 - lr: 1.5625e-05
# Epoch 59/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.8930 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2883 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0354 - lr: 1.5625e-05
# Epoch 60/160
# 114/114 [==============================] - 6s 55ms/step - loss: 2.8946 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2874 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0342 - lr: 1.5625e-05
# Epoch 61/160
# 114/114 [==============================] - 10s 84ms/step - loss: 2.8935 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2876 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0353 - lr: 1.5625e-05
# (5280, 1200, 7)
# (5280, 1200, 7)
# tf.Tensor(0.011841652, shape=(), dtype=float32) tf.Tensor(0.084168226, shape=(), dtype=float32)
# starting.... fold 2
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, 720, 7)]     0           []
#
#  targets (InputLayer)           [(None, 16, 7)]      0           []
#
#  stacked_sci_net_6 (StackedSciN  (None, 16, 7)       684292      ['inputs[0][0]',
#  et)                                                              'targets[0][0]']
#
# ==================================================================================================
# Total params: 684,292
# Trainable params: 684,292
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/160
# 114/114 [==============================] - 88s 308ms/step - loss: 33.9345 - mean_squared_error: 0.5703 - mean_absolute_error: 0.3296 - val_loss: 10.3249 - val_mean_squared_error: 0.0104 - val_mean_absolute_error: 0.0790 - lr: 0.0010
# Epoch 2/160
# 114/114 [==============================] - 7s 61ms/step - loss: 16.1059 - mean_squared_error: 0.0136 - mean_absolute_error: 0.0914 - val_loss: 9.3052 - val_mean_squared_error: 0.0075 - val_mean_absolute_error: 0.0664 - lr: 0.0010
# Epoch 3/160
# 114/114 [==============================] - 7s 62ms/step - loss: 14.3581 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0800 - val_loss: 8.3812 - val_mean_squared_error: 0.0074 - val_mean_absolute_error: 0.0662 - lr: 0.0010
# Epoch 4/160
# 114/114 [==============================] - 7s 60ms/step - loss: 12.9917 - mean_squared_error: 0.0089 - mean_absolute_error: 0.0730 - val_loss: 7.4919 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0574 - lr: 0.0010
# Epoch 5/160
# 114/114 [==============================] - 7s 60ms/step - loss: 11.6018 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0646 - val_loss: 6.6225 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0513 - lr: 0.0010
# Epoch 6/160
# 114/114 [==============================] - 7s 60ms/step - loss: 10.3578 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0584 - val_loss: 5.7767 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0477 - lr: 0.0010
# Epoch 7/160
# 114/114 [==============================] - 7s 60ms/step - loss: 9.1880 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0530 - val_loss: 4.9629 - val_mean_squared_error: 0.0036 - val_mean_absolute_error: 0.0446 - lr: 0.0010
# Epoch 8/160
# 114/114 [==============================] - 7s 61ms/step - loss: 8.0970 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0481 - val_loss: 4.1927 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0430 - lr: 0.0010
# Epoch 9/160
# 114/114 [==============================] - 7s 61ms/step - loss: 7.1920 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0454 - val_loss: 3.4800 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0397 - lr: 0.0010
# Epoch 10/160
# 114/114 [==============================] - 7s 61ms/step - loss: 6.3859 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0434 - val_loss: 2.8345 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0387 - lr: 0.0010
# Epoch 11/160
# 114/114 [==============================] - 7s 62ms/step - loss: 5.6451 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0411 - val_loss: 2.2675 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0377 - lr: 0.0010
# Epoch 12/160
# 114/114 [==============================] - 7s 62ms/step - loss: 5.0297 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0396 - val_loss: 1.7877 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0350 - lr: 0.0010
# Epoch 13/160
# 114/114 [==============================] - 6s 56ms/step - loss: 4.5634 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0391 - val_loss: 1.3977 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0352 - lr: 0.0010
# Epoch 14/160
# 114/114 [==============================] - 7s 59ms/step - loss: 4.1510 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0380 - val_loss: 1.0868 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0356 - lr: 0.0010
# Epoch 15/160
# 114/114 [==============================] - 7s 62ms/step - loss: 3.8575 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0377 - val_loss: 0.8551 - val_mean_squared_error: 0.0022 - val_mean_absolute_error: 0.0329 - lr: 0.0010
# Epoch 16/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.6241 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0371 - val_loss: 0.6841 - val_mean_squared_error: 0.0022 - val_mean_absolute_error: 0.0333 - lr: 0.0010
# Epoch 17/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.4556 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0367 - val_loss: 0.5663 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0344 - lr: 0.0010
# Epoch 18/160
# 114/114 [==============================] - 7s 57ms/step - loss: 3.3528 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0366 - val_loss: 0.4895 - val_mean_squared_error: 0.0022 - val_mean_absolute_error: 0.0330 - lr: 0.0010
# Epoch 19/160
# 114/114 [==============================] - 7s 63ms/step - loss: 3.2798 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0364 - val_loss: 0.4415 - val_mean_squared_error: 0.0021 - val_mean_absolute_error: 0.0322 - lr: 0.0010
# Epoch 20/160
# 114/114 [==============================] - 7s 58ms/step - loss: 3.2198 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0361 - val_loss: 0.4107 - val_mean_squared_error: 0.0021 - val_mean_absolute_error: 0.0328 - lr: 0.0010
# Epoch 21/160
# 114/114 [==============================] - 7s 58ms/step - loss: 3.1928 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0361 - val_loss: 0.3923 - val_mean_squared_error: 0.0021 - val_mean_absolute_error: 0.0327 - lr: 0.0010
# Epoch 22/160
# 114/114 [==============================] - 7s 57ms/step - loss: 3.1563 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0357 - val_loss: 0.3791 - val_mean_squared_error: 0.0021 - val_mean_absolute_error: 0.0322 - lr: 0.0010
# Epoch 23/160
# 114/114 [==============================] - 7s 57ms/step - loss: 3.1549 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0358 - val_loss: 0.3729 - val_mean_squared_error: 0.0021 - val_mean_absolute_error: 0.0325 - lr: 0.0010
# Epoch 24/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.1467 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0358 - val_loss: 0.3714 - val_mean_squared_error: 0.0022 - val_mean_absolute_error: 0.0333 - lr: 0.0010
# Epoch 25/160
# 114/114 [==============================] - 7s 61ms/step - loss: 3.0577 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0345 - val_loss: 0.3460 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0310 - lr: 5.0000e-04
# Epoch 26/160
# 114/114 [==============================] - 7s 62ms/step - loss: 3.0450 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0345 - val_loss: 0.3443 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0309 - lr: 5.0000e-04
# Epoch 27/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.0457 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0345 - val_loss: 0.3417 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0317 - lr: 5.0000e-04
# Epoch 28/160
# 114/114 [==============================] - 7s 60ms/step - loss: 3.0406 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0345 - val_loss: 0.3411 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0307 - lr: 5.0000e-04
# Epoch 29/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.0409 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0345 - val_loss: 0.3379 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0309 - lr: 5.0000e-04
# Epoch 30/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.0343 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0344 - val_loss: 0.3361 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0311 - lr: 5.0000e-04
# Epoch 31/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.0315 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0344 - val_loss: 0.3352 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0318 - lr: 5.0000e-04
# Epoch 32/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.0252 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0344 - val_loss: 0.3337 - val_mean_squared_error: 0.0021 - val_mean_absolute_error: 0.0326 - lr: 5.0000e-04
# Epoch 33/160
# 114/114 [==============================] - 7s 59ms/step - loss: 3.0351 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0346 - val_loss: 0.3337 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0309 - lr: 5.0000e-04
# Epoch 34/160
# 114/114 [==============================] - 7s 65ms/step - loss: 2.9720 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0337 - val_loss: 0.3156 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0306 - lr: 2.5000e-04
# Epoch 35/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.9697 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0337 - val_loss: 0.3136 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0304 - lr: 2.5000e-04
# Epoch 36/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.9707 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0338 - val_loss: 0.3131 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0302 - lr: 2.5000e-04
# Epoch 37/160
# 114/114 [==============================] - 7s 63ms/step - loss: 2.9698 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0338 - val_loss: 0.3122 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0303 - lr: 2.5000e-04
# Epoch 38/160
# 114/114 [==============================] - 8s 70ms/step - loss: 2.9683 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0337 - val_loss: 0.3122 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0310 - lr: 2.5000e-04
# Epoch 39/160
# 114/114 [==============================] - 6s 56ms/step - loss: 2.9683 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0338 - val_loss: 0.3102 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0312 - lr: 2.5000e-04
# Epoch 40/160
# 114/114 [==============================] - 6s 56ms/step - loss: 2.9660 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0338 - val_loss: 0.3107 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0303 - lr: 2.5000e-04
# Epoch 41/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.9716 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0339 - val_loss: 0.3107 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0307 - lr: 2.5000e-04
# Epoch 42/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.9315 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0333 - val_loss: 0.2959 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0302 - lr: 1.2500e-04
# Epoch 43/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.9286 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0333 - val_loss: 0.2960 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0300 - lr: 1.2500e-04
# Epoch 44/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.9307 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0334 - val_loss: 0.2963 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0302 - lr: 1.2500e-04
# Epoch 45/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.9292 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0334 - val_loss: 0.2941 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0304 - lr: 1.2500e-04
# Epoch 46/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.9265 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0334 - val_loss: 0.2950 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0300 - lr: 1.2500e-04
# Epoch 47/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.9258 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0333 - val_loss: 0.2945 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0299 - lr: 1.2500e-04
# Epoch 48/160
# 114/114 [==============================] - 6s 56ms/step - loss: 2.9278 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0334 - val_loss: 0.2944 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0307 - lr: 1.2500e-04
# Epoch 49/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.9244 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0334 - val_loss: 0.2927 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0303 - lr: 1.2500e-04
# Epoch 50/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.9220 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0333 - val_loss: 0.2930 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0311 - lr: 1.2500e-04
# Epoch 51/160
# 114/114 [==============================] - 7s 63ms/step - loss: 2.9194 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0333 - val_loss: 0.2918 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0297 - lr: 1.2500e-04
# Epoch 52/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.9207 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0334 - val_loss: 0.2902 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0305 - lr: 1.2500e-04
# Epoch 53/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.9203 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0333 - val_loss: 0.2903 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0305 - lr: 1.2500e-04
# Epoch 54/160
# 114/114 [==============================] - 6s 56ms/step - loss: 2.9238 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0334 - val_loss: 0.2906 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0305 - lr: 1.2500e-04
# Epoch 55/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.9206 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0334 - val_loss: 0.2900 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0304 - lr: 1.2500e-04
# Epoch 56/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.9186 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0334 - val_loss: 0.2886 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0299 - lr: 1.2500e-04
# Epoch 57/160
# 114/114 [==============================] - 6s 56ms/step - loss: 2.8913 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0330 - val_loss: 0.2778 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0297 - lr: 6.2500e-05
# Epoch 58/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.8879 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0330 - val_loss: 0.2776 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0297 - lr: 6.2500e-05
# Epoch 59/160
# 114/114 [==============================] - 7s 64ms/step - loss: 2.8877 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0330 - val_loss: 0.2756 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0297 - lr: 6.2500e-05
# Epoch 60/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.8857 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0330 - val_loss: 0.2768 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0298 - lr: 6.2500e-05
# Epoch 61/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8840 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0330 - val_loss: 0.2753 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0300 - lr: 6.2500e-05
# Epoch 62/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.8699 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2677 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0300 - lr: 3.1250e-05
# Epoch 63/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.8671 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2676 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0296 - lr: 3.1250e-05
# Epoch 64/160
# 114/114 [==============================] - 6s 56ms/step - loss: 2.8651 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2674 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0298 - lr: 3.1250e-05
# Epoch 65/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.8668 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2675 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0298 - lr: 3.1250e-05
# Epoch 66/160
# 114/114 [==============================] - 7s 65ms/step - loss: 2.8648 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2669 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0294 - lr: 3.1250e-05
# Epoch 67/160
# 114/114 [==============================] - 7s 63ms/step - loss: 2.8646 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2668 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0294 - lr: 3.1250e-05
# Epoch 68/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.8639 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2664 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 3.1250e-05
# Epoch 69/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8633 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2655 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0298 - lr: 3.1250e-05
# Epoch 70/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8621 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2655 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 3.1250e-05
# Epoch 71/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8614 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.2653 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 3.1250e-05
# Epoch 72/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.8530 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.2602 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0297 - lr: 1.5625e-05
# Epoch 73/160
# 114/114 [==============================] - 7s 63ms/step - loss: 2.8513 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.2596 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0293 - lr: 1.5625e-05
# Epoch 74/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.8528 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.2598 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0294 - lr: 1.5625e-05
# Epoch 75/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.8503 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.2599 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0300 - lr: 1.5625e-05
# Epoch 76/160
# 114/114 [==============================] - 7s 64ms/step - loss: 2.8500 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.2594 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0293 - lr: 1.5625e-05
# Epoch 77/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8445 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2560 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0296 - lr: 7.8125e-06
# Epoch 78/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8433 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2560 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 7.8125e-06
# Epoch 79/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.8434 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2560 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0296 - lr: 7.8125e-06
# Epoch 80/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.8443 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2561 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0294 - lr: 7.8125e-06
# Epoch 81/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8422 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2562 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0296 - lr: 7.8125e-06
# Epoch 82/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8397 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2540 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 3.9063e-06
# Epoch 83/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.8398 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2538 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 3.9063e-06
# Epoch 84/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.8408 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2536 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0294 - lr: 3.9063e-06
# Epoch 85/160
# 114/114 [==============================] - 7s 59ms/step - loss: 2.8373 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2535 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 3.9063e-06
# Epoch 86/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8383 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2533 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0294 - lr: 3.9063e-06
# Epoch 87/160
# 114/114 [==============================] - 6s 57ms/step - loss: 2.8364 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0325 - val_loss: 0.2524 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0296 - lr: 1.9531e-06
# Epoch 88/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8368 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2523 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 1.9531e-06
# Epoch 89/160
# 114/114 [==============================] - 7s 59ms/step - loss: 2.8393 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2525 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 1.9531e-06
# Epoch 90/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8379 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2522 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 1.9531e-06
# Epoch 91/160
# 114/114 [==============================] - 7s 57ms/step - loss: 2.8366 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2522 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0296 - lr: 1.9531e-06
# Epoch 92/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8370 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2516 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 9.7656e-07
# Epoch 93/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8359 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2515 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 9.7656e-07
# Epoch 94/160
# 114/114 [==============================] - 7s 58ms/step - loss: 2.8345 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0325 - val_loss: 0.2517 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 9.7656e-07
# Epoch 95/160
# 114/114 [==============================] - 7s 59ms/step - loss: 2.8358 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2516 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 9.7656e-07
# Epoch 96/160
# 114/114 [==============================] - 10s 91ms/step - loss: 2.8360 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.2514 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0295 - lr: 9.7656e-07
# (5280, 1200, 7)
# (5280, 1200, 7)
# tf.Tensor(0.010652115, shape=(), dtype=float32) tf.Tensor(0.07311322, shape=(), dtype=float32)
# starting.... fold 3
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, 720, 7)]     0           []
#
#  targets (InputLayer)           [(None, 16, 7)]      0           []
#
#  stacked_sci_net_7 (StackedSciN  (None, 16, 7)       684292      ['inputs[0][0]',
#  et)                                                              'targets[0][0]']
#
# ==================================================================================================
# Total params: 684,292
# Trainable params: 684,292
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/160
# 114/114 [==============================] - 89s 315ms/step - loss: 33.3762 - mean_squared_error: 0.5394 - mean_absolute_error: 0.3215 - val_loss: 10.1550 - val_mean_squared_error: 0.0084 - val_mean_absolute_error: 0.0721 - lr: 0.0010
# Epoch 2/160
# 114/114 [==============================] - 8s 68ms/step - loss: 15.8198 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0902 - val_loss: 9.0672 - val_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0623 - lr: 0.0010
# Epoch 3/160
# 114/114 [==============================] - 7s 63ms/step - loss: 14.0382 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0791 - val_loss: 8.1002 - val_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0613 - lr: 0.0010
# Epoch 4/160
# 114/114 [==============================] - 7s 64ms/step - loss: 12.6100 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0716 - val_loss: 7.1769 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0533 - lr: 0.0010
# Epoch 5/160
# 114/114 [==============================] - 7s 64ms/step - loss: 11.1763 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0630 - val_loss: 6.2815 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0493 - lr: 0.0010
# Epoch 6/160
# 114/114 [==============================] - 8s 66ms/step - loss: 9.9159 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0569 - val_loss: 5.4177 - val_mean_squared_error: 0.0034 - val_mean_absolute_error: 0.0446 - lr: 0.0010
# Epoch 7/160
# 114/114 [==============================] - 7s 64ms/step - loss: 8.7552 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0518 - val_loss: 4.5963 - val_mean_squared_error: 0.0031 - val_mean_absolute_error: 0.0418 - lr: 0.0010
# Epoch 8/160
# 114/114 [==============================] - 7s 64ms/step - loss: 7.6985 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0474 - val_loss: 3.8303 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0401 - lr: 0.0010
# Epoch 9/160
# 114/114 [==============================] - 8s 66ms/step - loss: 6.8353 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0454 - val_loss: 3.1330 - val_mean_squared_error: 0.0025 - val_mean_absolute_error: 0.0375 - lr: 0.0010
# Epoch 10/160
# 114/114 [==============================] - 7s 64ms/step - loss: 6.0339 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0430 - val_loss: 2.5162 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0358 - lr: 0.0010
# Epoch 11/160
# 114/114 [==============================] - 7s 63ms/step - loss: 5.3273 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0407 - val_loss: 1.9860 - val_mean_squared_error: 0.0022 - val_mean_absolute_error: 0.0343 - lr: 0.0010
# Epoch 12/160
# 114/114 [==============================] - 7s 57ms/step - loss: 4.7463 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0391 - val_loss: 1.5490 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0351 - lr: 0.0010
# Epoch 13/160
# 114/114 [==============================] - 7s 64ms/step - loss: 4.3231 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0386 - val_loss: 1.2012 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0330 - lr: 0.0010
# Epoch 14/160
# 114/114 [==============================] - 7s 58ms/step - loss: 3.9700 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0379 - val_loss: 0.9330 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0332 - lr: 0.0010
# Epoch 15/160
# 114/114 [==============================] - 6s 56ms/step - loss: 3.7242 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0376 - val_loss: 0.7409 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0331 - lr: 0.0010
# Epoch 16/160
# 114/114 [==============================] - 7s 62ms/step - loss: 3.5474 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0374 - val_loss: 0.6036 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0323 - lr: 0.0010
# Epoch 17/160
# 114/114 [==============================] - 7s 62ms/step - loss: 3.3992 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0367 - val_loss: 0.5101 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0318 - lr: 0.0010
# Epoch 18/160
# 114/114 [==============================] - 7s 62ms/step - loss: 3.3186 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0367 - val_loss: 0.4544 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0316 - lr: 0.0010
# Epoch 19/160
# 114/114 [==============================] - 6s 57ms/step - loss: 3.2626 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0365 - val_loss: 0.4212 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0325 - lr: 0.0010
# Epoch 20/160
# 114/114 [==============================] - 7s 58ms/step - loss: 3.2153 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0362 - val_loss: 0.3970 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0318 - lr: 0.0010
# Epoch 21/160
# 114/114 [==============================] - 7s 58ms/step - loss: 3.1975 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0362 - val_loss: 0.3850 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0322 - lr: 0.0010
# Epoch 22/160
# 114/114 [==============================] - 7s 57ms/step - loss: 3.1793 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0361 - val_loss: 0.3766 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0324 - lr: 0.0010
# Epoch 23/160
# ...
# Epoch 31/160
# 114/114 [==============================] - 7s 60ms/step - loss: 3.0543 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0344 - val_loss: 0.3775 - val_mean_squared_error: 0.0035 - val_mean_absolute_error: 0.0407 - lr: 0.0010
# Epoch 32/160
# 114/114 [==============================] - 8s 66ms/step - loss: 2.9696 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0333 - val_loss: 0.3509 - val_mean_squared_error: 0.0034 - val_mean_absolute_error: 0.0394 - lr: 5.0000e-04
# Epoch 33/160
# 114/114 [==============================] - 8s 68ms/step - loss: 2.9611 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0332 - val_loss: 0.3472 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0386 - lr: 5.0000e-04
# Epoch 34/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.9591 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0332 - val_loss: 0.3478 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0390 - lr: 5.0000e-04
# Epoch 35/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.9630 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0333 - val_loss: 0.3480 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0391 - lr: 5.0000e-04
# Epoch 36/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.9674 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0334 - val_loss: 0.3451 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0396 - lr: 5.0000e-04
# Epoch 37/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.9667 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0334 - val_loss: 0.3496 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0388 - lr: 5.0000e-04
# Epoch 38/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.9603 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0333 - val_loss: 0.3502 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0396 - lr: 5.0000e-04
# Epoch 39/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.9123 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.3262 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0386 - lr: 2.5000e-04
# Epoch 40/160
# 114/114 [==============================] - 7s 65ms/step - loss: 2.9058 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.3247 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0385 - lr: 2.5000e-04
# Epoch 41/160
# 114/114 [==============================] - 7s 66ms/step - loss: 2.9037 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.3242 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0384 - lr: 2.5000e-04
# Epoch 42/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.9010 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.3250 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0386 - lr: 2.5000e-04
# Epoch 43/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.9021 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.3265 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0386 - lr: 2.5000e-04
# Epoch 44/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.9053 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.3257 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0389 - lr: 2.5000e-04
# Epoch 45/160
# 114/114 [==============================] - 8s 67ms/step - loss: 2.9021 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.3244 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0382 - lr: 2.5000e-04
# Epoch 46/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.9029 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.3236 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0388 - lr: 2.5000e-04
# Epoch 47/160
# 114/114 [==============================] - 8s 68ms/step - loss: 2.9031 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.3235 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0387 - lr: 2.5000e-04
# Epoch 48/160
# 114/114 [==============================] - 8s 67ms/step - loss: 2.9013 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.3224 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0380 - lr: 2.5000e-04
# Epoch 49/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.9036 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0329 - val_loss: 0.3222 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0381 - lr: 2.5000e-04
# Epoch 50/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.8968 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0327 - val_loss: 0.3225 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0383 - lr: 2.5000e-04
# Epoch 51/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.8972 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0327 - val_loss: 0.3212 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0387 - lr: 2.5000e-04
# Epoch 52/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.8997 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.3217 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0388 - lr: 2.5000e-04
# Epoch 53/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.9019 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0329 - val_loss: 0.3214 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0390 - lr: 2.5000e-04
# Epoch 54/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.8510 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0323 - val_loss: 0.2998 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0387 - lr: 1.2500e-04
# Epoch 55/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.8469 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0323 - val_loss: 0.2995 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0381 - lr: 1.2500e-04
# Epoch 56/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.8445 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0323 - val_loss: 0.2984 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0381 - lr: 1.2500e-04
# Epoch 57/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.8422 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0322 - val_loss: 0.2994 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0388 - lr: 1.2500e-04
# Epoch 58/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.8452 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0323 - val_loss: 0.2984 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0385 - lr: 1.2500e-04
# Epoch 59/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.8169 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0320 - val_loss: 0.2838 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0382 - lr: 6.2500e-05
# Epoch 60/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.8138 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0320 - val_loss: 0.2838 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0382 - lr: 6.2500e-05
# Epoch 61/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.8092 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0319 - val_loss: 0.2837 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0383 - lr: 6.2500e-05
# Epoch 62/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.8133 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0320 - val_loss: 0.2835 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0383 - lr: 6.2500e-05
# Epoch 63/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.8117 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0320 - val_loss: 0.2821 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0381 - lr: 6.2500e-05
# Epoch 64/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.7967 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0318 - val_loss: 0.2739 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0382 - lr: 3.1250e-05
# Epoch 65/160
# 114/114 [==============================] - 8s 67ms/step - loss: 2.7944 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0318 - val_loss: 0.2735 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0380 - lr: 3.1250e-05
# Epoch 66/160
# 114/114 [==============================] - 7s 66ms/step - loss: 2.7935 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0318 - val_loss: 0.2729 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 3.1250e-05
# Epoch 67/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.7946 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0318 - val_loss: 0.2724 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0382 - lr: 3.1250e-05
# Epoch 68/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.7918 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0318 - val_loss: 0.2729 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 3.1250e-05
# Epoch 69/160
# 114/114 [==============================] - 7s 65ms/step - loss: 2.7904 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0318 - val_loss: 0.2721 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 3.1250e-05
# Epoch 70/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.7910 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0318 - val_loss: 0.2712 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 3.1250e-05
# Epoch 71/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.7894 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0318 - val_loss: 0.2706 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0380 - lr: 3.1250e-05
# Epoch 72/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.7811 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.2657 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0381 - lr: 1.5625e-05
# Epoch 73/160
# 114/114 [==============================] - 7s 59ms/step - loss: 2.7785 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.2650 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0380 - lr: 1.5625e-05
# Epoch 74/160
# 114/114 [==============================] - 7s 65ms/step - loss: 2.7774 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.2651 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 1.5625e-05
# Epoch 75/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.7774 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.2644 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 1.5625e-05
# Epoch 76/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.7790 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.2642 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0380 - lr: 1.5625e-05
# Epoch 77/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.7729 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.2613 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 7.8125e-06
# Epoch 78/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.7696 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.2608 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 7.8125e-06
# Epoch 79/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.7705 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.2609 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 7.8125e-06
# Epoch 80/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.7719 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.2605 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 7.8125e-06
# Epoch 81/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.7681 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2606 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 7.8125e-06
# Epoch 82/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.7685 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2587 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 3.9063e-06
# Epoch 83/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.7674 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2584 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 3.9063e-06
# Epoch 84/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.7678 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2584 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 3.9063e-06
# Epoch 85/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.7663 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2581 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 3.9063e-06
# Epoch 86/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.7653 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2582 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 3.9063e-06
# Epoch 87/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.7632 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2570 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 1.9531e-06
# Epoch 88/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.7646 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2568 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 1.9531e-06
# Epoch 89/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.7627 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2567 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0379 - lr: 1.9531e-06
# Epoch 90/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.7654 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2568 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 1.9531e-06
# Epoch 91/160
# 114/114 [==============================] - 7s 61ms/step - loss: 2.7648 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2567 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 1.9531e-06
# Epoch 92/160
# 114/114 [==============================] - 7s 60ms/step - loss: 2.7637 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2561 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 9.7656e-07
# Epoch 93/160
# 114/114 [==============================] - 7s 62ms/step - loss: 2.7648 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2560 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 9.7656e-07
# Epoch 94/160
# 114/114 [==============================] - 10s 90ms/step - loss: 2.7647 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.2560 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0378 - lr: 9.7656e-07
# (5280, 1200, 7)
# (5280, 1200, 7)
# tf.Tensor(0.009424458, shape=(), dtype=float32) tf.Tensor(0.073504224, shape=(), dtype=float32)

# %% [markdown]
# # V 3.0

# %% [markdown]
# ### SciNet - W 720 - S 1 - T 320

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
window = 720
stride = 1

# %%
from typing import Tuple
import tensorflow as tf
from tensorflow.keras.regularizers import L1L2


class InnerConv1DBlock(tf.keras.layers.Layer):
    def __init__(self, filters: int, h: float, kernel_size: int, neg_slope: float = .01, dropout: float = .5, **kwargs):
        if filters <= 0 or h <= 0:
            raise ValueError('filters and h must be positive')
        super(InnerConv1DBlock, self).__init__(**kwargs)
        self.conv1d = tf.keras.layers.Conv1D(max(round(h * filters), 1), kernel_size, padding='same')
        self.leakyrelu = tf.keras.layers.LeakyReLU(neg_slope)

        self.dropout = tf.keras.layers.Dropout(dropout)

        self.conv1d2 = tf.keras.layers.Conv1D(filters, kernel_size, padding='same')
        self.tanh = tf.keras.activations.tanh

    def call(self, input_tensor, training=None):
        x = self.conv1d(input_tensor)
        x = self.leakyrelu(x)

        if training:
            x = self.dropout(x)

        x = self.conv1d2(x)
        x = self.tanh(x)
        return x


class SciBlock(tf.keras.layers.Layer):
    def __init__(self, features: int, kernel_size: int, h: int, **kwargs):
        """
        :param features: number of features in the output
        :param kernel_size: kernel size of the convolutional layers
        :param h: scaling factor for convolutional module
        """

        super(SciBlock, self).__init__(**kwargs)
        self.features = features
        self.kernel_size = kernel_size
        self.h = h

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'features': self.features,
            'kernel_size': self.kernel_size,
            'h': self.h,
        })
        return config

    def build(self, input_shape):
        self.conv1ds = {k: InnerConv1DBlock(filters=self.features, h=self.h, kernel_size=self.kernel_size, name=k)
                        for k in ['psi', 'phi', 'eta', 'rho']}  # regularize?
        super().build(input_shape)
        # [layer.build(input_shape) for layer in self.conv1ds.values()]  # unneeded?

    def call(self, inputs, training=None):
        F_odd, F_even = inputs[:, ::2], inputs[:, 1::2]

        # Interactive learning as described in the paper
        F_s_odd = F_odd * tf.math.exp(self.conv1ds['phi'](F_even))
        F_s_even = F_even * tf.math.exp(self.conv1ds['psi'](F_odd))

        F_prime_odd = F_s_odd + self.conv1ds['rho'](F_s_even)
        F_prime_even = F_s_even - self.conv1ds['eta'](F_s_odd)

        return F_prime_odd, F_prime_even


class Interleave(tf.keras.layers.Layer):
    """A layer used to reverse the even-odd split operation."""

    def __init__(self, **kwargs):
        super(Interleave, self).__init__(**kwargs)

    def interleave(self, slices):
        if not slices:
            return slices
        elif len(slices) == 1:
            return slices[0]

        mid = len(slices) // 2
        even = self.interleave(slices[:mid])
        odd = self.interleave(slices[mid:])

        shape = tf.shape(even)
        return tf.reshape(tf.stack([even, odd], axis=3), (shape[0], shape[1] * 2, shape[2]))

    def call(self, inputs):
        return self.interleave(inputs)


class SciNet(tf.keras.layers.Layer):
    def __init__(self, horizon: int, features: int, levels: int, h: int, kernel_size: int,
                 regularizer: Tuple[float, float] = (0, 0), **kwargs):
        """
        :param horizon: number of time stamps in output
        :param features: number of features in output
        :param levels: height of the binary tree + 1
        :param h: scaling factor for convolutional module in each SciBlock
        :param kernel_size: kernel size of convolutional module in each SciBlock
        :param regularizer: activity regularization (not implemented)
        """

        if levels < 1:
            raise ValueError('Must have at least 1 level')
        super(SciNet, self).__init__(**kwargs)
        self.horizon = horizon
        self.features = features
        self.levels = levels
        self.interleave = Interleave()
        self.flatten = tf.keras.layers.Flatten()
        self.dense = tf.keras.layers.Dense(
            horizon * features,
            kernel_regularizer=L1L2(0.001, 0.01),
            # activity_regularizer=L1L2(0.001, 0.01)
        )
        # self.regularizer = tf.keras.layers.ActivityRegularization(l1=regularizer[0], l2=regularizer[1])

        # tree of sciblocks
        self.sciblocks = [SciBlock(features=features, kernel_size=kernel_size, h=h)
                          for _ in range(2 ** levels - 1)]

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'horizon': self.horizon,
            'features': self.features,
            'levels': self.levels,
            'interleave': self.interleave,
            'flatten': self.flatten,
            'dense': self.dense,
            'sciblocks': self.sciblocks,
        })
        return config

    def build(self, input_shape):
        if input_shape[1] / 2 ** self.levels % 1 != 0:
            raise ValueError(f'timestamps {input_shape[1]} must be evenly divisible by a tree with '
                             f'{self.levels} levels')
        super().build(input_shape)
        # [layer.build(input_shape) for layer in self.sciblocks]  # input_shape

    def call(self, inputs, training=None):
        # cascade input down a binary tree of sci-blocks
        lvl_inputs = [inputs]  # inputs for current level of the tree
        for i in range(self.levels):
            i_end = 2 ** (i + 1) - 1
            i_start = i_end - 2 ** i
            lvl_outputs = [output for j, tensor in zip(range(i_start, i_end), lvl_inputs)
                           for output in self.sciblocks[j](tensor)]
            lvl_inputs = lvl_outputs

        x = self.interleave(lvl_outputs)
        x += inputs

        # not sure if this is the correct way of doing it. The paper merely said to use a fully connected layer to
        # produce an output. Can't use TimeDistributed wrapper. It would force the layer's timestamps to match that of
        # the input -- something SCINet is supposed to solve
        x = self.flatten(x)
        x = self.dense(x)
        x = tf.reshape(x, (-1, self.horizon, self.features))

        return x


class StackedSciNet(tf.keras.layers.Layer):
    def __init__(self, horizon: int, features: int, stacks: int, levels: int, h: int, kernel_size: int,
                 regularizer: Tuple[float, float] = (0, 0), **kwargs):
        """
        :param horizon: number of time stamps in output
        :param stacks: number of stacked SciNets
        :param levels: number of levels for each SciNet
        :param h: scaling factor for convolutional module in each SciBlock
        :param kernel_size: kernel size of convolutional module in each SciBlock
        :param regularizer: activity regularization (not implemented)
        """

        if stacks < 1:
            raise ValueError('Must have at least 1 stack')
        super(StackedSciNet, self).__init__(**kwargs)
        self.horizon = horizon
        self.features = features
        self.stacks = stacks
        self.levels = levels
        self.h = h
        self.kernel_size = kernel_size
        self.regularizer = regularizer
        self.scinets = [SciNet(horizon=horizon, features=features, levels=levels, h=h, kernel_size=kernel_size,
                               regularizer=regularizer) for _ in range(stacks)]
        self.mse_fn = tf.keras.metrics.MeanSquaredError()
        self.mae_fn = tf.keras.metrics.MeanAbsoluteError()

    # def build(self, input_shape):
    #     super().build(input_shape)
    #     [stack.build(input_shape) for stack in self.scinets]

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'horizon': self.horizon,
            'features': self.features,
            'stacks': self.stacks,
            'levels': self.levels,
            'h': self.h,
            'kernel_size': self.kernel_size,
            'regularizer': self.regularizer,
        })
        return config

    def call(self, inputs, targets=None, sample_weights=None, training=None):
        outputs = []
        for scinet in self.scinets:
            x = scinet(inputs)
            outputs.append(x)  # keep each stack's output for intermediate supervision
            inputs = tf.concat([x, inputs[:, x.shape[1]:, :]], axis=1)

        if targets is not None:
            # Calculate metrics
            mse = self.mse_fn(targets, x, sample_weights)
            mae = self.mae_fn(targets, x, sample_weights)
            self.add_metric(mse, name='mean_squared_error')
            self.add_metric(mae, name='mean_absolute_error')

            if training:
                # Calculate loss as sum of mean of norms of differences between output and input feature vectors for
                # each stack
                stacked_outputs = tf.stack(outputs)
                differences = stacked_outputs - targets
                loss = tf.linalg.normalize(differences, axis=1)[1]
                loss = tf.reshape(loss, (-1, self.horizon))
                loss = tf.reduce_sum(loss, 1)
                loss = loss / self.horizon
                loss = tf.reduce_sum(loss)
                self.add_loss(loss)

        return x

# %%
target_labels = dataset.columns
telescope = 320

# %%
batch_size = 512
epochs = 160

# %%
def make_model(input_shape, output_shape):
    inputs = tf.keras.Input(shape=(window, 7), name='inputs')
    # x = SciNet(horizon, levels=L, h=h, kernel_size=kernel_size)(inputs)
    # model = tf.keras.Model(inputs, x)
    targets = tf.keras.Input(shape=(telescope, 7), name='targets')
    predictions = StackedSciNet(horizon=telescope, features=input_shape[-1], stacks=1, levels=4, h=4,
                                kernel_size=5,
                                regularizer=(1e-3, 0.1))(inputs, targets)
    model = tf.keras.Model(inputs=[inputs, targets], outputs=predictions)

    model.summary()
    tf.keras.utils.plot_model(model, to_file='modelDiagram.png', show_shapes=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse',
                  metrics=['mean_squared_error', 'mean_absolute_error'])
    return model

# %%
num_folds=6

single_interval = math.floor(len(X_train_raw)/num_folds)

intervals = []
current = 0
for i in range(num_folds):
  intervals.append(current)
  current += single_interval

intervals.append(len(X_train_raw) - 1)

print(len(X_train_raw))
print(intervals)
# Out:
# 68528
# [0, 11421, 22842, 34263, 45684, 57105, 68527]

# %%
# K-fold Cross Validation model evaluation
for fold in range(num_folds):
  print("starting.... fold "+str(fold+1))
  X_train = np.array([])
  y_train = np.array([])
  X_validation = np.array([])
  y_validation = np.array([])

  validation_raw = np.array([])

  #Create sequences from different folds
  for i in range(num_folds):
    data = X_train_raw[intervals[i]:intervals[i+1]]
    if (fold == i):
      X_validation, y_validation = build_sequences(data, target_labels, window, stride, telescope)
      validation_raw = data.copy()
    elif len(X_train) == 0:
      X_train, y_train = build_sequences(data, target_labels, window, stride, telescope)
    else:
      X_temp, y_temp = build_sequences(data, target_labels, window, stride, telescope)
      X_train = np.concatenate((X_train, X_temp), axis=0)
      y_train = np.concatenate((y_train, y_temp), axis=0)

  input_shape = X_train.shape[1:]
  output_shape = y_train.shape[1:]

  #BUILD THE MODEL
  with strategy.scope():
    model = make_model(input_shape, output_shape)

  history = model.fit(
    x = {'inputs': X_train, 'targets': y_train},
    y = y_train,
    validation_data={'inputs': X_validation, 'targets': y_validation},
    batch_size = batch_size,
    epochs = epochs,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-8)
    ]
  ).history

  reg_telescope = 1280
  X_validation_reg, y_validation_reg = build_sequences(validation_raw, target_labels, window, stride, reg_telescope)

  reg_predictions = np.array([])
  X_temp = X_validation_reg
  placeholder = np.empty([len(X_temp),telescope, 7])
  for reg in range(0,reg_telescope,telescope):
      pred_temp = model.predict({'inputs': X_temp, 'targets': placeholder})
      if(len(reg_predictions)==0):
          reg_predictions = pred_temp
      else:
          reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
      X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)
  
  print(y_validation_reg.shape)
  print(reg_predictions.shape)

  mean_squared_error = tfk.metrics.mse(y_validation_reg.flatten(),reg_predictions.flatten())
  mean_absolute_error = tfk.metrics.mae(y_validation_reg.flatten(),reg_predictions.flatten())
  print(mean_squared_error, mean_absolute_error)
# Out:
# starting.... fold 1
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, 720, 7)]     0           []
#
#  targets (InputLayer)           [(None, 320, 7)]     0           []
#
#  stacked_sci_net (StackedSciNet  (None, 320, 7)      11411540    ['inputs[0][0]',
#  )                                                                'targets[0][0]']
#
# ==================================================================================================
# Total params: 11,411,540
# Trainable params: 11,411,540
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/160
# 103/103 [==============================] - 94s 398ms/step - loss: 117.4283 - mean_squared_error: 0.4551 - mean_absolute_error: 0.2821 - val_loss: 27.0927 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0968 - lr: 0.0010
# Epoch 2/160
# 103/103 [==============================] - 7s 73ms/step - loss: 15.8596 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0784 - val_loss: 3.1987 - val_mean_squared_error: 0.0096 - val_mean_absolute_error: 0.0753 - lr: 0.0010
# Epoch 3/160
# 103/103 [==============================] - 7s 72ms/step - loss: 7.7257 - mean_squared_error: 0.0093 - mean_absolute_error: 0.0711 - val_loss: 1.9860 - val_mean_squared_error: 0.0098 - val_mean_absolute_error: 0.0759 - lr: 0.0010
# Epoch 4/160
# 103/103 [==============================] - 7s 72ms/step - loss: 6.8930 - mean_squared_error: 0.0087 - mean_absolute_error: 0.0678 - val_loss: 1.5492 - val_mean_squared_error: 0.0109 - val_mean_absolute_error: 0.0794 - lr: 0.0010
# Epoch 5/160
# 103/103 [==============================] - 7s 72ms/step - loss: 6.5215 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0671 - val_loss: 1.4285 - val_mean_squared_error: 0.0142 - val_mean_absolute_error: 0.0942 - lr: 0.0010
# Epoch 6/160
# 103/103 [==============================] - 7s 65ms/step - loss: 6.4233 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0662 - val_loss: 1.4714 - val_mean_squared_error: 0.0174 - val_mean_absolute_error: 0.1070 - lr: 0.0010
# Epoch 7/160
# 103/103 [==============================] - 7s 64ms/step - loss: 6.4117 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0652 - val_loss: 1.5196 - val_mean_squared_error: 0.0161 - val_mean_absolute_error: 0.1033 - lr: 0.0010
# Epoch 8/160
# 103/103 [==============================] - 7s 64ms/step - loss: 6.4227 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0646 - val_loss: 1.5760 - val_mean_squared_error: 0.0132 - val_mean_absolute_error: 0.0892 - lr: 0.0010
# Epoch 9/160
# 103/103 [==============================] - 7s 64ms/step - loss: 6.3826 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0633 - val_loss: 1.6088 - val_mean_squared_error: 0.0142 - val_mean_absolute_error: 0.0945 - lr: 0.0010
# Epoch 10/160
# 103/103 [==============================] - 7s 65ms/step - loss: 6.3557 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0624 - val_loss: 1.6445 - val_mean_squared_error: 0.0161 - val_mean_absolute_error: 0.0998 - lr: 0.0010
# Epoch 11/160
# 103/103 [==============================] - 8s 75ms/step - loss: 5.7192 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0602 - val_loss: 1.0866 - val_mean_squared_error: 0.0156 - val_mean_absolute_error: 0.0986 - lr: 5.0000e-04
# Epoch 12/160
# 103/103 [==============================] - 7s 65ms/step - loss: 5.6908 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0601 - val_loss: 1.1173 - val_mean_squared_error: 0.0162 - val_mean_absolute_error: 0.0996 - lr: 5.0000e-04
# Epoch 13/160
# 103/103 [==============================] - 7s 64ms/step - loss: 5.7088 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0601 - val_loss: 1.1441 - val_mean_squared_error: 0.0130 - val_mean_absolute_error: 0.0870 - lr: 5.0000e-04
# Epoch 14/160
# 103/103 [==============================] - 7s 65ms/step - loss: 5.7143 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0599 - val_loss: 1.1600 - val_mean_squared_error: 0.0168 - val_mean_absolute_error: 0.1010 - lr: 5.0000e-04
# Epoch 15/160
# 103/103 [==============================] - 7s 65ms/step - loss: 5.7076 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0595 - val_loss: 1.1888 - val_mean_squared_error: 0.0171 - val_mean_absolute_error: 0.1008 - lr: 5.0000e-04
# Epoch 16/160
# 103/103 [==============================] - 7s 65ms/step - loss: 5.7207 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0594 - val_loss: 1.2170 - val_mean_squared_error: 0.0159 - val_mean_absolute_error: 0.0968 - lr: 5.0000e-04
# Epoch 17/160
# 103/103 [==============================] - 7s 72ms/step - loss: 5.2679 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0577 - val_loss: 0.8148 - val_mean_squared_error: 0.0158 - val_mean_absolute_error: 0.0973 - lr: 2.5000e-04
# Epoch 18/160
# 103/103 [==============================] - 7s 65ms/step - loss: 5.2465 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0578 - val_loss: 0.8273 - val_mean_squared_error: 0.0182 - val_mean_absolute_error: 0.1045 - lr: 2.5000e-04
# Epoch 19/160
# 103/103 [==============================] - 7s 65ms/step - loss: 5.2506 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0577 - val_loss: 0.8381 - val_mean_squared_error: 0.0184 - val_mean_absolute_error: 0.1043 - lr: 2.5000e-04
# Epoch 20/160
# 103/103 [==============================] - 7s 64ms/step - loss: 5.2525 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0577 - val_loss: 0.8553 - val_mean_squared_error: 0.0160 - val_mean_absolute_error: 0.0968 - lr: 2.5000e-04
# Epoch 21/160
# 103/103 [==============================] - 7s 66ms/step - loss: 5.2580 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0576 - val_loss: 0.8514 - val_mean_squared_error: 0.0174 - val_mean_absolute_error: 0.1031 - lr: 2.5000e-04
# Epoch 22/160
# 103/103 [==============================] - 7s 65ms/step - loss: 5.2448 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0574 - val_loss: 0.8693 - val_mean_squared_error: 0.0179 - val_mean_absolute_error: 0.1027 - lr: 2.5000e-04
# Epoch 23/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.9628 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0565 - val_loss: 0.6052 - val_mean_squared_error: 0.0165 - val_mean_absolute_error: 0.0980 - lr: 1.2500e-04
# Epoch 24/160
# 103/103 [==============================] - 7s 68ms/step - loss: 4.9478 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0566 - val_loss: 0.6078 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0946 - lr: 1.2500e-04
# Epoch 25/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.9436 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0565 - val_loss: 0.6178 - val_mean_squared_error: 0.0164 - val_mean_absolute_error: 0.0990 - lr: 1.2500e-04
# Epoch 26/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.9430 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0565 - val_loss: 0.6163 - val_mean_squared_error: 0.0161 - val_mean_absolute_error: 0.0984 - lr: 1.2500e-04
# Epoch 27/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.9345 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0564 - val_loss: 0.6208 - val_mean_squared_error: 0.0157 - val_mean_absolute_error: 0.0973 - lr: 1.2500e-04
# Epoch 28/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.9322 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0564 - val_loss: 0.6135 - val_mean_squared_error: 0.0159 - val_mean_absolute_error: 0.0970 - lr: 1.2500e-04
# Epoch 29/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.7488 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0557 - val_loss: 0.4551 - val_mean_squared_error: 0.0156 - val_mean_absolute_error: 0.0960 - lr: 6.2500e-05
# Epoch 30/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.7310 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0557 - val_loss: 0.4582 - val_mean_squared_error: 0.0159 - val_mean_absolute_error: 0.0963 - lr: 6.2500e-05
# Epoch 31/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.7312 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0557 - val_loss: 0.4573 - val_mean_squared_error: 0.0161 - val_mean_absolute_error: 0.0973 - lr: 6.2500e-05
# Epoch 32/160
# 103/103 [==============================] - 7s 73ms/step - loss: 4.7285 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0557 - val_loss: 0.4548 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0956 - lr: 6.2500e-05
# Epoch 33/160
# 103/103 [==============================] - 7s 72ms/step - loss: 4.7222 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0556 - val_loss: 0.4538 - val_mean_squared_error: 0.0166 - val_mean_absolute_error: 0.0990 - lr: 6.2500e-05
# Epoch 34/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.7164 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0556 - val_loss: 0.4560 - val_mean_squared_error: 0.0170 - val_mean_absolute_error: 0.0997 - lr: 6.2500e-05
# Epoch 35/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.7137 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0555 - val_loss: 0.4550 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0951 - lr: 6.2500e-05
# Epoch 36/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.7086 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0555 - val_loss: 0.4578 - val_mean_squared_error: 0.0174 - val_mean_absolute_error: 0.1003 - lr: 6.2500e-05
# Epoch 37/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.7044 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0554 - val_loss: 0.4551 - val_mean_squared_error: 0.0162 - val_mean_absolute_error: 0.0973 - lr: 6.2500e-05
# Epoch 38/160
# 103/103 [==============================] - 7s 71ms/step - loss: 4.7022 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0554 - val_loss: 0.4566 - val_mean_squared_error: 0.0176 - val_mean_absolute_error: 0.1010 - lr: 6.2500e-05
# Epoch 39/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.5917 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0550 - val_loss: 0.3571 - val_mean_squared_error: 0.0183 - val_mean_absolute_error: 0.1029 - lr: 3.1250e-05
# Epoch 40/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.5757 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0549 - val_loss: 0.3552 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.1012 - lr: 3.1250e-05
# Epoch 41/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.5744 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0549 - val_loss: 0.3560 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.1017 - lr: 3.1250e-05
# Epoch 42/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.5707 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0549 - val_loss: 0.3563 - val_mean_squared_error: 0.0184 - val_mean_absolute_error: 0.1038 - lr: 3.1250e-05
# Epoch 43/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.5682 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0549 - val_loss: 0.3553 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.1020 - lr: 3.1250e-05
# Epoch 44/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.5660 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0548 - val_loss: 0.3567 - val_mean_squared_error: 0.0182 - val_mean_absolute_error: 0.1026 - lr: 3.1250e-05
# Epoch 45/160
# 103/103 [==============================] - 8s 73ms/step - loss: 4.5623 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0548 - val_loss: 0.3551 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.1017 - lr: 3.1250e-05
# Epoch 46/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.5577 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0547 - val_loss: 0.3522 - val_mean_squared_error: 0.0186 - val_mean_absolute_error: 0.1038 - lr: 3.1250e-05
# Epoch 47/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.5525 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0547 - val_loss: 0.3561 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1058 - lr: 3.1250e-05
# Epoch 48/160
# 103/103 [==============================] - 8s 73ms/step - loss: 4.5520 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0547 - val_loss: 0.3512 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.1022 - lr: 3.1250e-05
# Epoch 49/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.5477 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0546 - val_loss: 0.3528 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1048 - lr: 3.1250e-05
# Epoch 50/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.5448 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0546 - val_loss: 0.3522 - val_mean_squared_error: 0.0182 - val_mean_absolute_error: 0.1030 - lr: 3.1250e-05
# Epoch 51/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.5431 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0546 - val_loss: 0.3533 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.1061 - lr: 3.1250e-05
# Epoch 52/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.5383 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0545 - val_loss: 0.3549 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1058 - lr: 3.1250e-05
# Epoch 53/160
# 103/103 [==============================] - 8s 75ms/step - loss: 4.5354 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0545 - val_loss: 0.3518 - val_mean_squared_error: 0.0176 - val_mean_absolute_error: 0.1011 - lr: 3.1250e-05
# Epoch 54/160
# 103/103 [==============================] - 8s 76ms/step - loss: 4.4712 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0543 - val_loss: 0.2954 - val_mean_squared_error: 0.0181 - val_mean_absolute_error: 0.1031 - lr: 1.5625e-05
# Epoch 55/160
# 103/103 [==============================] - 8s 75ms/step - loss: 4.4632 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0543 - val_loss: 0.2947 - val_mean_squared_error: 0.0189 - val_mean_absolute_error: 0.1051 - lr: 1.5625e-05
# Epoch 56/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.4596 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0542 - val_loss: 0.2943 - val_mean_squared_error: 0.0193 - val_mean_absolute_error: 0.1061 - lr: 1.5625e-05
# Epoch 57/160
# 103/103 [==============================] - 8s 73ms/step - loss: 4.4573 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0542 - val_loss: 0.2933 - val_mean_squared_error: 0.0183 - val_mean_absolute_error: 0.1031 - lr: 1.5625e-05
# Epoch 58/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.4581 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0542 - val_loss: 0.2947 - val_mean_squared_error: 0.0182 - val_mean_absolute_error: 0.1023 - lr: 1.5625e-05
# Epoch 59/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.4546 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0542 - val_loss: 0.2945 - val_mean_squared_error: 0.0187 - val_mean_absolute_error: 0.1040 - lr: 1.5625e-05
# Epoch 60/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.4542 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0542 - val_loss: 0.2953 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.1022 - lr: 1.5625e-05
# Epoch 61/160
# 103/103 [==============================] - 8s 73ms/step - loss: 4.4517 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0541 - val_loss: 0.2926 - val_mean_squared_error: 0.0183 - val_mean_absolute_error: 0.1041 - lr: 1.5625e-05
# Epoch 62/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.4486 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0541 - val_loss: 0.2929 - val_mean_squared_error: 0.0181 - val_mean_absolute_error: 0.1025 - lr: 1.5625e-05
# Epoch 63/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.4477 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0541 - val_loss: 0.2927 - val_mean_squared_error: 0.0192 - val_mean_absolute_error: 0.1052 - lr: 1.5625e-05
# Epoch 64/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.4449 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0541 - val_loss: 0.2930 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1048 - lr: 1.5625e-05
# Epoch 65/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.4404 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0540 - val_loss: 0.2918 - val_mean_squared_error: 0.0195 - val_mean_absolute_error: 0.1061 - lr: 1.5625e-05
# Epoch 66/160
# 103/103 [==============================] - 8s 75ms/step - loss: 4.4385 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0540 - val_loss: 0.2908 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1055 - lr: 1.5625e-05
# Epoch 67/160
# 103/103 [==============================] - 7s 67ms/step - loss: 4.4358 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0540 - val_loss: 0.2915 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1047 - lr: 1.5625e-05
# Epoch 68/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.4347 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0540 - val_loss: 0.2925 - val_mean_squared_error: 0.0185 - val_mean_absolute_error: 0.1028 - lr: 1.5625e-05
# Epoch 69/160
# 103/103 [==============================] - 7s 67ms/step - loss: 4.4302 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0539 - val_loss: 0.2915 - val_mean_squared_error: 0.0191 - val_mean_absolute_error: 0.1052 - lr: 1.5625e-05
# Epoch 70/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.4320 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0539 - val_loss: 0.2910 - val_mean_squared_error: 0.0187 - val_mean_absolute_error: 0.1043 - lr: 1.5625e-05
# Epoch 71/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.4265 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0539 - val_loss: 0.2911 - val_mean_squared_error: 0.0196 - val_mean_absolute_error: 0.1059 - lr: 1.5625e-05
# Epoch 72/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3914 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0537 - val_loss: 0.2582 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1053 - lr: 7.8125e-06
# Epoch 73/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3845 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0537 - val_loss: 0.2588 - val_mean_squared_error: 0.0187 - val_mean_absolute_error: 0.1037 - lr: 7.8125e-06
# Epoch 74/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3828 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0537 - val_loss: 0.2589 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1046 - lr: 7.8125e-06
# Epoch 75/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3833 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0537 - val_loss: 0.2575 - val_mean_squared_error: 0.0197 - val_mean_absolute_error: 0.1066 - lr: 7.8125e-06
# Epoch 76/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3823 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0537 - val_loss: 0.2576 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.1060 - lr: 7.8125e-06
# Epoch 77/160
# 103/103 [==============================] - 7s 67ms/step - loss: 4.3809 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0537 - val_loss: 0.2580 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1048 - lr: 7.8125e-06
# Epoch 78/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3789 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0537 - val_loss: 0.2591 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1039 - lr: 7.8125e-06
# Epoch 79/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.3756 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0536 - val_loss: 0.2579 - val_mean_squared_error: 0.0193 - val_mean_absolute_error: 0.1050 - lr: 7.8125e-06
# Epoch 80/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3759 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0536 - val_loss: 0.2577 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1043 - lr: 7.8125e-06
# Epoch 81/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3565 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2407 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1040 - lr: 3.9063e-06
# Epoch 82/160
# 103/103 [==============================] - 8s 73ms/step - loss: 4.3531 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2398 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1037 - lr: 3.9063e-06
# Epoch 83/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3544 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2396 - val_mean_squared_error: 0.0191 - val_mean_absolute_error: 0.1048 - lr: 3.9063e-06
# Epoch 84/160
# 103/103 [==============================] - 7s 73ms/step - loss: 4.3515 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2396 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1043 - lr: 3.9063e-06
# Epoch 85/160
# 103/103 [==============================] - 7s 72ms/step - loss: 4.3524 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0536 - val_loss: 0.2393 - val_mean_squared_error: 0.0189 - val_mean_absolute_error: 0.1042 - lr: 3.9063e-06
# Epoch 86/160
# 103/103 [==============================] - 7s 65ms/step - loss: 4.3503 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2397 - val_mean_squared_error: 0.0184 - val_mean_absolute_error: 0.1032 - lr: 3.9063e-06
# Epoch 87/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3509 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2391 - val_mean_squared_error: 0.0186 - val_mean_absolute_error: 0.1034 - lr: 3.9063e-06
# Epoch 88/160
# 103/103 [==============================] - 7s 73ms/step - loss: 4.3479 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2389 - val_mean_squared_error: 0.0191 - val_mean_absolute_error: 0.1048 - lr: 3.9063e-06
# Epoch 89/160
# 103/103 [==============================] - 8s 73ms/step - loss: 4.3484 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2386 - val_mean_squared_error: 0.0191 - val_mean_absolute_error: 0.1048 - lr: 3.9063e-06
# Epoch 90/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3486 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2388 - val_mean_squared_error: 0.0187 - val_mean_absolute_error: 0.1032 - lr: 3.9063e-06
# Epoch 91/160
# 103/103 [==============================] - 8s 76ms/step - loss: 4.3461 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2383 - val_mean_squared_error: 0.0191 - val_mean_absolute_error: 0.1044 - lr: 3.9063e-06
# Epoch 92/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3463 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0535 - val_loss: 0.2381 - val_mean_squared_error: 0.0193 - val_mean_absolute_error: 0.1052 - lr: 3.9063e-06
# Epoch 93/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3455 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0535 - val_loss: 0.2382 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.1051 - lr: 3.9063e-06
# Epoch 94/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3437 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.2387 - val_mean_squared_error: 0.0191 - val_mean_absolute_error: 0.1045 - lr: 3.9063e-06
# Epoch 95/160
# 103/103 [==============================] - 7s 67ms/step - loss: 4.3438 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0535 - val_loss: 0.2382 - val_mean_squared_error: 0.0192 - val_mean_absolute_error: 0.1042 - lr: 3.9063e-06
# Epoch 96/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3433 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.2387 - val_mean_squared_error: 0.0191 - val_mean_absolute_error: 0.1042 - lr: 3.9063e-06
# Epoch 97/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3415 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.2378 - val_mean_squared_error: 0.0191 - val_mean_absolute_error: 0.1046 - lr: 3.9063e-06
# Epoch 98/160
# 103/103 [==============================] - 7s 67ms/step - loss: 4.3410 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.2381 - val_mean_squared_error: 0.0193 - val_mean_absolute_error: 0.1050 - lr: 3.9063e-06
# Epoch 99/160
# 103/103 [==============================] - 7s 67ms/step - loss: 4.3418 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.2382 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1044 - lr: 3.9063e-06
# Epoch 100/160
# 103/103 [==============================] - 8s 75ms/step - loss: 4.3384 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.2377 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1035 - lr: 3.9063e-06
# Epoch 101/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3366 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.2379 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.1049 - lr: 3.9063e-06
# Epoch 102/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3371 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.2376 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1042 - lr: 3.9063e-06
# Epoch 103/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3352 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.2376 - val_mean_squared_error: 0.0189 - val_mean_absolute_error: 0.1038 - lr: 3.9063e-06
# Epoch 104/160
# 103/103 [==============================] - 7s 66ms/step - loss: 4.3356 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0533 - val_loss: 0.2378 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1034 - lr: 3.9063e-06
# Epoch 105/160
# 103/103 [==============================] - 7s 67ms/step - loss: 4.3360 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.2379 - val_mean_squared_error: 0.0189 - val_mean_absolute_error: 0.1040 - lr: 3.9063e-06
# Epoch 106/160
# 103/103 [==============================] - 7s 67ms/step - loss: 4.3340 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0533 - val_loss: 0.2377 - val_mean_squared_error: 0.0187 - val_mean_absolute_error: 0.1032 - lr: 3.9063e-06
# Epoch 107/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3340 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0533 - val_loss: 0.2371 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1039 - lr: 3.9063e-06
# Epoch 108/160
# 103/103 [==============================] - 8s 75ms/step - loss: 4.3319 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0533 - val_loss: 0.2368 - val_mean_squared_error: 0.0192 - val_mean_absolute_error: 0.1044 - lr: 3.9063e-06
# Epoch 109/160
# 103/103 [==============================] - 8s 74ms/step - loss: 4.3312 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0533 - val_loss: 0.2368 - val_mean_squared_error: 0.0192 - val_mean_absolute_error: 0.1040 - lr: 3.9063e-06
# Epoch 110/160
# 103/103 [==============================] - 7s 68ms/step - loss: 4.3325 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0533 - val_loss: 0.2370 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1037 - lr: 3.9063e-06
# Epoch 111/160
# 103/103 [==============================] - 7s 67ms/step - loss: 4.3293 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0533 - val_loss: 0.2371 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.1037 - lr: 3.9063e-06
# Epoch 112/160
# 103/103 [==============================] - 7s 68ms/step - loss: 4.3294 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0533 - val_loss: 0.2371 - val_mean_squared_error: 0.0189 - val_mean_absolute_error: 0.1033 - lr: 3.9063e-06
# Epoch 113/160
#  77/103 [=====================>........] - ETA: 1s - loss: 4.3305 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0532
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-0952317b0d99> in <module>()
#      37     callbacks = [
#      38         tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
# ---> 39         tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-8)
#      40     ]
#      41   ).history
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:
